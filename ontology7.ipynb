# %% [markdown]
#  #  Ontology Of Factors Affecting Global Virtual Team (GVT) Performance In Global Software Development(GSD)
# This project aims to build an ontology of Global Virtual Teams (GVTs)Performance Develop in Global Software Development(GSD) through the use of a set of concepts and the relationships that link them and the characteristics that represent the features of each concept and the restrictions imposed on these characteristics, where ontology with class instances forms a knowledge base that helps in obtaining a broader understanding of factors affecting GSD.

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
#pip install owlready2

# %% [markdown]
# # Creat And Save Ontology

# %%
from owlready2 import *
import ontor
import webbrowser
import os
#ontoname="GVTPDOnto19852" #prefix
def select_drive(x):# Functions to select drive to save ontology in.
    global drive   
    if "D" in x or "d" in x:
        drive="D:\\ "      
    else: 
        if "E" in x or "e" in x:
            drive="E:\\ " 
        else:
            if "F" in x or "f" in x:
                drive="F:\\ "
            else:
                print("Wrong Input!")
                query = input("Enter the correct drive: D , E or F:")
                select_drive (query)
prefix= input("Enter ontology name to save: or press C to canceled ")
if "C" in prefix or "c" in prefix:      
    print("save file canceled")
else:    
    query = input("Which drive do you want to save in ? D , E or F:")
    select_drive(query)
    onto = get_ontology("http://www.semanticweb.org/dell/ontologies/2023/3/"+prefix+"#")
    filePath=drive+prefix+".owl"
    onto.save(filePath, format = "rdfxml")
    print("Ontology saved in:"+drive+prefix+".owl")
# Out:
# Enter ontology name to save: or press C to canceled GvtOntoInGsd
# Which drive do you want to save in ? D , E or F:e
# Ontology saved in:E:\ GvtOntoInGsd.owl

# %%
onto.metadata.label=[prefix]
#التعليق يمثل abstract
onto.metadata.comment=["This ontology aims to describe factors affecting of Global Virtual Teams (GVTs)Performance in Global Software Development(GSD) through the use of a set of concepts and the relationships that link them and the characteristics that represent the features of each concept and the restrictions imposed on these characteristics, where ontology with class instances forms a knowledge base that helps in obtaining a broader understanding of factors affecting GSD."]
onto.metadata.versionInfo=["version 0.1"]
onto.metadata.seeAlso=["Master Student Ahmed R. Abd .Shaheen,Prof. Dr. Laheeb M. I. Alzubaidy"]                
namespac=onto.get_namespace("http://www.semanticweb.org/dell/ontologies/2022/0/"+prefix)
with onto:
    class creator(AnnotationProperty):pass
    onto.metadata.creator=[" Master Student Ahmed R. Abd .Shaheen,Prof. Dr. Laheeb M. I. Alzubaidy  University of Mosul-College of Computer Sciences & Math – Software  Dept  "] 
    class timeCreated(AnnotationProperty):pass
    onto.metadata.timeCreated=["2023"]
    class preferdNamespacePrefix(AnnotationProperty):pass
    onto.metadata.preferdNamespacePrefix=[prefix]
    class preferdNamespaceUri(AnnotationProperty):pass
    onto.metadata.preferdNamespaceUri=["http://www.semanticweb.org/dell/ontologies/2023/3/"+prefix]

# %%
print(onto.base_iri)
print(namespac)
# Out:
# http://www.semanticweb.org/dell/ontologies/2023/3/GvtOntoInGsd#
# get_ontology("http://www.semanticweb.org/dell/ontologies/2023/3/GvtOntoInGsd#").get_namespace("http://www.semanticweb.org/dell/ontologies/2022/0/GvtOntoInGsd#")

# %% [markdown]
# # Creating Classes And  Annotation

# %%
with onto:
    class GVTPerformanceInGSD(Thing): pass  
    GVTPerformanceInGSD.comment=["The class represents a measurement to measure, evaluate, or judge the extent to which an individual or team has succeeded in achieving the desired result through a set of measurable criteria. "]
    GVTPerformanceInGSD.label=["GVT Performance In GSD"]
##persons factor
    class Person(Thing): pass
    Person.comment=["The class represents persons involved in Global Software Development using Global Virtual Teams."]
    Person.label=["Person"]
    Person.isDefinedBy.append("http://xmlns.com/foaf/0.1/")
    class equivalentClass(AnnotationProperty):pass
    Person.equivalentClass=["http://xmlns.com/foaf/0.1/Person"]
    class GeographicalDiversity(Thing): pass
    GeographicalDiversity.comment = ["The class represents the countries in which the persons of Global Virtual Teams belong."]
    GeographicalDiversity.label = ["Geographical Diversity"]
    class TimeZoneDifferent(Thing): pass
    TimeZoneDifferent.comment = ["Class represents the time difference between the countries in which the persons of Global Virtual Teams belong."]
    TimeZoneDifferent.label = ["Time Zone Different"]
    class FollowTheSunApproach(Thing): pass
    FollowTheSunApproach.comment = ["The class represents a type of global knowledge workflow designed to reduce time to market, where work is delivered at the end of the day to the next production site located over several time zones west to continue that work."]
    FollowTheSunApproach.label = ["Follow The Sun Approach"]
    class WorkTime(Thing): pass
    WorkTime.comment = ["The class represents the increase in the global virtual team's daily working time resulting from the use of a Follow The Sun approach."]
    WorkTime.label = ["Work Time"]
    class ICTDifferent(Thing): pass
    ICTDifferent.comment = ["The class represents all the devices, networks, applications, and systems that collectively allow persons to interact in the digital world."]
    ICTDifferent.label = ["Information and Communication Technology Different"]
    class Asynchronous(ICTDifferent): pass
    Asynchronous.comment = ["The class represents all devices, networks, applications, and systems that collectively allow people to interact in the digital world and does not take place in real-time."]
    Asynchronous.label = ["Asynchronous"]
    class Synchronous(ICTDifferent): pass
    Synchronous.comment = ["The class represents all the devices, networks, applications, and systems that collectively allow people to interact in the digital world and it take place in real-time."]
    Synchronous.label = ["Synchronous"]
    class TravelCostsAndTime(Thing): pass
    TravelCostsAndTime.comment = ["The class represents the cost and time spent by Global Virtual Team members moving between locations."]
    TravelCostsAndTime.label = ["Travel Costs And Time"]
    class WorkFromAnywhereInWorld(Thing): pass
    WorkFromAnywhereInWorld.comment = ["The class represents the places from which the Global Virtual Team members accomplish the tasks assigned to them."]
    WorkFromAnywhereInWorld.label = ["Work From Any where In World"]
    class DiversityOfSkills(Thing): pass
    DiversityOfSkills.comment = ["The class represents the knowledge and skill available as a result of geographical diversity."]
    DiversityOfSkills.label = ["Diversity Of Skills"]
    class CultureDifferences(Thing): pass 
    CultureDifferences.comment = ["The class represents the socially acquired values, practices, and rules of behavior that influence the range of acceptable behaviors for people and can be distinguished from person to person."]
    CultureDifferences.label = ["Culture Differences"]
    class LanguageDifferent(Thing): pass
    LanguageDifferent.comment = ["The class  represents the different languages spoken by members of the global virtual team."]
    LanguageDifferent.label = ["Language Different"]
    class Company(Thing): pass
    Company.comment = ["The class represents companies that develop software and information technology."]
    Company.label = ["Company"]
    class Policies(Thing): pass
    Policies.comment = ["The class represents a set of guidelines that are written to explain in general the requirements of the company and how employees will be treated."]
    Policies.label = ["Policies"]
# project
    class Project(Thing): pass
    Project.comment = ["The class represents the project which is a series of tasks that must be completed in order to reach a specific result. "]
    Project.label = ["Project"]
    class TaskSets(Thing): pass
    TaskSets.comment = ["The class represents a collection of software engineering work tasks, milestones, and deliverables that must be accomplished to complete a particular software project."]
    TaskSets.label = ["Task Sets"]    
    class WorkTasks(Thing): pass
    WorkTasks.comment = ["The class represents a refinement of a major task set."]
    WorkTasks.label = ["Work Tasks"]    
    class Team(Thing): pass
    Team.comment = ["The class represents a group of person linked in a common purpose."]                                                 
    Team.label = ["Team"]   
    class Leadership(Thing): pass
    Leadership.comment = ["The class represents the Team Leader of a virtual team that leads and directs other team members to achieve the desired goals"]
    Leadership.label = ["Leadership"]    
    class Communication(Thing): pass
    Communication.comment = ["The class represents the method of social interaction between people and the process of exchanging information between the sender or receiver ."]
    Communication.label = ["Communication"]    
    class Formal(Communication): pass
    Formal.comment = ["The class represents the method of social interaction between people and the process of exchanging information between the sender or receiver according to dictate by the established hierarchical organization of the business."]        
    Formal.label = ["Formal"]    
    class Informal(Communication): pass
    Informal.comment = ["The class represents the method of social interaction between people and the process of exchanging information between the sender or receiver  and is based on informal social relationships that are formed in the workplace outside the normal hierarchy of business structure."]
    Informal.label = ["Informal"]   
    class Cooperation(Thing): pass
    Cooperation.comment = ["The class represents the act or process of working together to get something done for a common purpose or to achieve mutual benefit."]
    Cooperation.label = ["Cooperation"]   
    class Coordination(Thing): pass
    Coordination.comment = ["The process responsible for securing communication between the functional levels in the organizational structure vertically and helping to integrate the functional positions horizontally in order to achieve the set goals."]
    Coordination.label = ["Coordination"]   
    class Trust(Thing): pass
    Trust.comment = ["It is the state in which a person is certain of the efficiency or accuracy of something related to him or to a person or something else."]
    Trust.label = ["Trust"]    
    class Cohesion(Thing): pass
    Cohesion.comment = ["The cohesion of the team expresses the strength of the group's attraction to its members, the close agreement between them in pursuit of its own goals ."]
    Cohesion.label = ["Cohesion"]   
    class KnowledgeSharing(Thing): pass
    KnowledgeSharing .comment = ["The class represents Sharing information about a subject that you get by experience or study, either known by one person or by people generally"]
    KnowledgeSharing.label = ["KnowledgeSharing"]    
    class Motivation(Thing): pass
    Motivation.comment = ["The class represents the drive which encourages team members to work in a virtual project team."]
    Motivation.label = ["Motivation"]
    class Compliment(Motivation): pass
    Compliment.comment = ["The class represents express your approval, admiration, or respect to someone for that person's character, skill."]
    Compliment.label = ["Compliment"]
    class Reward(Motivation): pass
    Reward.comment = ["The class represents  something given in exchange for a useful idea, good behavior, excellent work."]
    Reward.label = ["Reward"]   
    class Conflict(Thing): pass
    Conflict.comment = ["The class represents an active disagreement, as between opposing opinions or needs or principles."]
    Conflict.label = ["Conflict"]  
    class StaffTurnover(Thing): pass
    StaffTurnover.comment = ["The class represents  the percentage of employees who leave an organization during a certain period of time."]
    StaffTurnover.label = ["Staff Turnover"]    
    class ReliabilityOfInformation(Thing): pass
    ReliabilityOfInformation.comment = ["Information is said to be reliable if it can be verified and evaluated. or the extent to which we can rely on the source of the data."]
    ReliabilityOfInformation.label = ["ReliabilityOfInformation"]    
    class DataRepositories(Thing): pass
    DataRepositories.comment = ["The class represents a place where data are stored and can be found."]
    DataRepositories.label = ["Data Repositories"]    
    class ComfortEnvironment(Thing): pass
    ComfortEnvironment.comment = ["The class represents Geographical location and surrounding conditions in which employees work, including offices, facility building, work tools, lighting, air and noise."]
    ComfortEnvironment.label = ["Comfort Environment"]    
    class TechnicalProblems(Thing): pass
    TechnicalProblems.comment = ["The class represents incorrect evaluation of required technology, construction methods, or project phases."]
    TechnicalProblems.label = ["Technical Problems"]    
    class LackOfOrganizationalStructure(Thing): pass
    LackOfOrganizationalStructure.comment = ["The class represents the Poor way in which a large corporation or organization is organized,"]
    LackOfOrganizationalStructure.label = ["LackOfOrganizationalStructure"]    
    class Training(Thing): pass
    Training.comment = ["The class represents the process of learning the skills you need to do a particular job or activity"]
    Training.label = ["Training"]    
    class Experience(Thing): pass
    Experience.comment = ["The process of getting knowledge or skill from doing, seeing, or feeling things."]
    Experience.label = ["Experience"]    
    class TeamSize(Thing): pass
    TeamSize.comment = ["The class represents the number of person on the team."]
    TeamSize.label = ["Team Size"]
    class FactorsImpactedbySize(Thing): pass
    FactorsImpactedbySize.comment = ["The class represents the factors that are impacted by team size increases."]
    FactorsImpactedbySize.label = ["FactorsImpacted by Size"]
    class Teamness(Thing): pass
    Teamness.comment = ["The class represents a feeling of belonging that arises in a group of individuals towards the same work."]
    Teamness.label = ["Teamness"]
#Process
    class Process(Thing): pass
    Process.comment = ["The class represents the software process which is a collection of activities, actions, and tasks that are performed when some work products are to be created."]
    Process.label = ["Process"]    
    class ProcessFramework(Thing): pass
    ProcessFramework.comment = ["The class represents  Framework  or model which contains activities, actions, and tasks, and defines their relationship to each other."]
    ProcessFramework.label = ["Process Framework"]    
    class FrameworkActivities(Thing): pass
    FrameworkActivities.comment = ["The class represents the activities that are populated by a set of  software engineering action."]
    FrameworkActivities.label = ["Framework Activities"]    
    class MarketplaceDemands(Thing): pass
    MarketplaceDemands.comment = ["The class represents the demand of all possible customers for a particular product or service over a particular period of time in a particular market."]
    MarketplaceDemands.label = ["Market place Demands"]    
    class RequirementProblem(Thing): pass
    RequirementProblem .comment = ["The class represents the problems in the features and functions that the target system should have."]
    RequirementProblem.label = ["Requirement Problem"]    
    class FaultyDefinition(RequirementProblem): pass
    FaultyDefinition .comment = ["The class represents the Wrong definition of features and functions that the target system should have."]
    FaultyDefinition.label = ["Faulty Definition"]    
    class RequirementsNotUnderstood(RequirementProblem): pass
    RequirementsNotUnderstood.comment = ["The class represents the not understanding of features and functions that the target system should have."]
    RequirementsNotUnderstood.label = ["Requirements Not Understood"]    
    class RequirementChange(RequirementProblem): pass
    RequirementChange.comment = ["The class represents a change in the features and functions that the target system should have."]
    RequirementChange.label = ["Requirement Change"]    
    class FrameworkActivitiesPrinciples(Thing): pass
    FrameworkActivitiesPrinciples.comment = ["The class represents principles or guidelines that help developers succeed in each activity and represents a specific general framework as part of the software process."]
    FrameworkActivitiesPrinciples.label = ["Not Use Framework Activities Principles"]    
    class DesignProblems(Thing): pass
    DesignProblems.comment = ["The Class represents design problems."]
    DesignProblems.label = ["Design Problems"]
    class CodingProblems(Thing): pass
    CodingProblems .comment = ["The Class represents coding problems."]
    CodingProblems.label = ["Coding Problems"]   
    class DocumentationProblems(Thing): pass 
    DocumentationProblems .comment = ["The Class represents documentation problems."]
    DocumentationProblems.label = ["Documentation Problems"]
    class TestingAndMaintenanceDifficult(Thing): pass
    TestingAndMaintenanceDifficult.comment = ["The Class Represents  Testing And Maintenance Difficult ."]
    TestingAndMaintenanceDifficult.label = ["Testing And Maintenance Difficult"]    
# Product
    class Product(Thing): pass
    Product.comment = ["The class represents the product which is a software product delivered to the customer with the documentation that describes how to install and use the system. "]
    Product.label = ["Product"]   
    class Goal(Thing): pass
    Goal.comment = ["The class represents what the product to be developed is supposed to achieve."]
    Goal.label = ["Goal"]
    class Scope(Thing): pass  
    Scope.comment = ["The class represents the features or characteristics of a product itself."]
    Scope.label = ["Scope"]   
    class Cost(Thing): pass
    Cost.comment = ["The class represents amount of money needed to buy,  or make a product:"]
    Cost.label = ["Cost"]   
    class GoalOfProximityToHumanResources(Thing): pass
    GoalOfProximityToHumanResources.comment = ["The class represents the benefit of being close to human resource sources."]
    GoalOfProximityToHumanResources.label = ["Goal Of Proximity To Human Resources"]
    class LowOfficeCosts(GoalOfProximityToHumanResources): pass
    LowOfficeCosts.comment = ["The class represents lower Costs related to the operation of the business location."]
    LowOfficeCosts.label = ["Low Office Costs"]    
    class LowWages(GoalOfProximityToHumanResources): pass
    LowWages.comment = ["The class represents lower Costs related to employees."]
    LowWages.label = ["Low Wages"]    
    class Time(Thing): pass
    Time.comment = ["The class represents the product delivery deadline."]
    Time.label = ["Time"]
    class WorkTasksScheduling(Thing): pass 
    WorkTasksScheduling .comment = ["The class represents an activity that distributes estimated effort across the planned project duration by allocating the effort to specific software engineering tasks"]
    WorkTasksScheduling.label = ["Work Tasks Scheduling"]    
    class Quality(Thing): pass
    Quality.comment = ["The degree to which a system, component, or process meets customer or user needs or expectations."]
    Quality.label = ["Quality"]
    class QualityFactors(Thing): pass
    QualityFactors.comment = ["The class represents software quality factors"]
    QualityFactors.label = ["Quality Factors"]    
    class NewnessTechnology(Thing): pass
    NewnessTechnology.comment = ["The class represents the novelty of the technology in which the product operates."]
    NewnessTechnology.label = ["Newness Technology"]    
    class StakeholderParticipationEarly(Thing): pass
    StakeholderParticipationEarly.comment = ["The class represents the stages of stakeholder participation in product development"]
    StakeholderParticipationEarly.label = ["Stakeholder Participation Early"]    
    class SWComplexity(Thing): pass
    SWComplexity.comment = ["The class represents the degree of software  complexity measured by the cyclomatic complexity scale v(G)."]
    SWComplexity.label = ["SW Complexity"]    
    class SWSize(Thing): pass
    SWSize.comment = ["The class represents the number of conditions in the program."]
    SWSize.label = ["SW Size"]
    class Resources(Thing): pass
    Resources.comment = ["The class represents the components required to build the software."]
    Resources.label = ["Resources"]        
    class Person(Resources): pass        
    class ReusableSoftware(Resources): pass   
    ReusableSoftware.comment = ["The class represents the creation and reuse of reusable software components."]
    ReusableSoftware.label = ["Reusable Software"]    
    class SEE(Resources): pass
    SEE.comment = ["The class represents the software engineering environment(SEE) that supports the software project"]
    SEE.label = ["Software Engineering Enviroment"]    
    class HW(SEE): pass
    HW.comment = ["The class represents the hardware that provides a platform that supports the software required to produce the work products that are an outcome of good software engineering practice."]
    HW.label = ["Hardware"]
    class NetworkResource(SEE): pass
    NetworkResource.comment = ["The class represents Elements of hardware, software or data that are related to networks"]
    NetworkResource.label = ["Network Resource"]    
    class SWTools(SEE): pass
    SWTools.comment = ["The class represents software required to produce the work products that are an outcome of good software engineering practice."]
    SWTools.label = ["Software Tools"]

# %%
a=list(onto.classes())
print(len (a))
# Out:
# 78

# %%
list(onto.classes())
# Out:
# [GvtOntoInGsd.GVTPerformanceInGSD,
#  GvtOntoInGsd.Person,
#  GvtOntoInGsd.GeographicalDiversity,
#  GvtOntoInGsd.TimeZoneDifferent,
#  GvtOntoInGsd.FollowTheSunApproach,
#  GvtOntoInGsd.WorkTime,
#  GvtOntoInGsd.ICTDifferent,
#  GvtOntoInGsd.Asynchronous,
#  GvtOntoInGsd.Synchronous,
#  GvtOntoInGsd.TravelCostsAndTime,
#  GvtOntoInGsd.WorkFromAnywhereInWorld,
#  GvtOntoInGsd.DiversityOfSkills,
#  GvtOntoInGsd.CultureDifferences,
#  GvtOntoInGsd.LanguageDifferent,
#  GvtOntoInGsd.Company,
#  GvtOntoInGsd.Policies,
#  GvtOntoInGsd.Project,
#  GvtOntoInGsd.TaskSets,
#  GvtOntoInGsd.WorkTasks,
#  GvtOntoInGsd.Team,
#  GvtOntoInGsd.Leadership,
#  GvtOntoInGsd.Communication,
#  GvtOntoInGsd.Formal,
#  GvtOntoInGsd.Informal,
#  GvtOntoInGsd.Cooperation,
#  GvtOntoInGsd.Coordination,
#  GvtOntoInGsd.Trust,
#  GvtOntoInGsd.Cohesion,
#  GvtOntoInGsd.KnowledgeSharing,
#  GvtOntoInGsd.Motivation,
#  GvtOntoInGsd.Compliment,
#  GvtOntoInGsd.Reward,
#  GvtOntoInGsd.Conflict,
# ...

# %%
for i in onto.classes():
    print("Class :",i,"    Class label:",i.label ,"\n","Class Description :",i.comment)
# Out:
# Class : GvtOntoInGsd.GVTPerformanceInGSD     Class label: ['GVT Performance In GSD']
#  Class Description : ['The class represents a measurement to measure, evaluate, or judge the extent to which an individual or team has succeeded in achieving the desired result through a set of measurable criteria. ']
# Class : GvtOntoInGsd.Person     Class label: ['Person']
#  Class Description : ['The class represents persons involved in Global Software Development using Global Virtual Teams.']
# Class : GvtOntoInGsd.GeographicalDiversity     Class label: ['Geographical Diversity']
#  Class Description : ['The class represents the countries in which the persons of Global Virtual Teams belong.']
# Class : GvtOntoInGsd.TimeZoneDifferent     Class label: ['Time Zone Different']
#  Class Description : ['Class represents the time difference between the countries in which the persons of Global Virtual Teams belong.']
# ...

# %%
#onto1=get_ontology("D:\\ss.owl").load()
#onto.imported_ontologies.append(onto1)
#with onto:
     
    #Person.equivalent_to=[onto1.Person]
     #onto1.Person.is_a.append(onto.Thing)

# %% [markdown]
# # Classes Disjoint

# %%
AllDisjoint([GVTPerformanceInGSD,GeographicalDiversity,TimeZoneDifferent,FollowTheSunApproach,WorkTime,
 ICTDifferent,TravelCostsAndTime,WorkFromAnywhereInWorld,DiversityOfSkills,CultureDifferences,LanguageDifferent,Company,
Policies,Project,TaskSets,WorkTasks,Team,Leadership,Communication,Cooperation,Coordination,Trust,Cohesion,
KnowledgeSharing,Motivation,Conflict,StaffTurnover,ReliabilityOfInformation,DataRepositories,
ComfortEnvironment,TechnicalProblems,LackOfOrganizationalStructure,Training,Experience, TeamSize,FactorsImpactedbySize,
Teamness,Process,ProcessFramework,FrameworkActivities,MarketplaceDemands,RequirementProblem,
FrameworkActivitiesPrinciples, DesignProblems,CodingProblems,DocumentationProblems,
TestingAndMaintenanceDifficult,Product,Goal,Scope,Cost,GoalOfProximityToHumanResources,
Time,WorkTasksScheduling,Quality,QualityFactors,NewnessTechnology,StakeholderParticipationEarly,
SWComplexity,SWSize,Resources])#بدون اشخاص
# Out:
# AllDisjoint([GvtOntoInGsd.GVTPerformanceInGSD, GvtOntoInGsd.GeographicalDiversity, GvtOntoInGsd.TimeZoneDifferent, GvtOntoInGsd.FollowTheSunApproach, GvtOntoInGsd.WorkTime, GvtOntoInGsd.ICTDifferent, GvtOntoInGsd.TravelCostsAndTime, GvtOntoInGsd.WorkFromAnywhereInWorld, GvtOntoInGsd.DiversityOfSkills, GvtOntoInGsd.CultureDifferences, GvtOntoInGsd.LanguageDifferent, GvtOntoInGsd.Company, GvtOntoInGsd.Policies, GvtOntoInGsd.Project, GvtOntoInGsd.TaskSets, GvtOntoInGsd.WorkTasks, GvtOntoInGsd.Team, GvtOntoInGsd.Leadership, GvtOntoInGsd.Communication, GvtOntoInGsd.Cooperation, GvtOntoInGsd.Coordination, GvtOntoInGsd.Trust, GvtOntoInGsd.Cohesion, GvtOntoInGsd.KnowledgeSharing, GvtOntoInGsd.Motivation, GvtOntoInGsd.Conflict, GvtOntoInGsd.StaffTurnover, GvtOntoInGsd.ReliabilityOfInformation, GvtOntoInGsd.DataRepositories, GvtOntoInGsd.ComfortEnvironment, GvtOntoInGsd.TechnicalProblems, GvtOntoInGsd.LackOfOrganizationalStructure, GvtOntoInGsd.Training, GvtOntoInGsd.Experience, GvtOntoInGsd.T
# ...

# %%
#list(Person.disjoints())

# %%
#close_world(onto)

# %% [markdown]
# # Creating Object properties

# %%
    with onto:
        class isAffectedFirstlyBy(GVTPerformanceInGSD >> Person) :pass
        isAffectedFirstlyBy.comment = ["Object property linking an instance of the class GVTPerformanceInGSD to an instance of the class Person."]                                                 
        isAffectedFirstlyBy.label = ["Is Affected Firstly By"]   
        class isTheFirstEffectOn(Person >> GVTPerformanceInGSD):pass 
        isTheFirstEffectOn.comment = ["Object property linking an instance of the class Person to an instance of the class GVTPerformanceInGSD."]                                                 
        isTheFirstEffectOn.label = ["Is The First Effect On"]
        isAffectedFirstlyBy.inverse_property=isTheFirstEffectOn
        class isAffectedSecondlyBy(GVTPerformanceInGSD >> Project) :pass
        isAffectedSecondlyBy.comment = ["Object property linking an instance of the class GVTPerformanceInGSD to an instance of the class Project."]                                                 
        isAffectedSecondlyBy.label = ["Is Affected Secondly By"]
        class isTheSecondEffectOn(Project >> GVTPerformanceInGSD):pass
        isTheSecondEffectOn.comment = ["Object property linking an instance of the class Project to an instance of the class GVTPerformanceInGSD."]                                                 
        isTheSecondEffectOn.label = ["Is The Second Effect On"]
        isAffectedSecondlyBy.inverse_property=isTheSecondEffectOn
        class isAffectedThirdlyBy(GVTPerformanceInGSD >> Process) :pass
        isAffectedThirdlyBy.comment = ["Object property linking an instance of the class GVTPerformanceInGSD to an instance of the class Process."]                                                 
        isAffectedThirdlyBy.label = ["Is Affected Thirdly By"]
        class isTheThirdEffectOn(Process >> GVTPerformanceInGSD):pass
        isTheThirdEffectOn.comment = ["Object property linking an instance of the class Process to an instance of the class GVTPerformanceInGSD."]                                                 
        isTheThirdEffectOn.label = ["Is The Third Effect On"]
        isAffectedThirdlyBy.inverse_property=isTheThirdEffectOn
        class isAffectedFourthlyBy(GVTPerformanceInGSD >> Product) :pass
        isAffectedFourthlyBy.comment = ["Object property linking an instance of the class GVTPerformanceInGSD to an instance of the class Product."]                                                 
        isAffectedFourthlyBy.label = ["Is Affected Fourthly By"]
        class isTheFourthEffectOn(Product >> GVTPerformanceInGSD):pass             
        isTheFourthEffectOn.comment = ["Object property linking an instance of the class Product to an instance of the class GVTPerformanceInGSD."]                                                 
        isTheFourthEffectOn.label = ["Is The Fourth Effect On"]
        isAffectedFourthlyBy.inverse_property=isTheFourthEffectOn    
        class isADeveloperFor(Person >>Product ): pass
        isADeveloperFor.comment = ["Object property linking an instance of the class Person to an instance of the class Product."]                                                 
        isADeveloperFor.label = ["Is A Developer For"]
        class isDevelopedBy(Product >>Person ): pass   
        isADeveloperFor.inverse_property=isDevelopedBy
        isDevelopedBy.comment = ["Object property linking an instance of the class Product to an instance of the class Person."]                                                 
        isDevelopedBy.label = ["Is Developed By"]
        class assigneTo(Person >>Project ): pass
        assigneTo.comment = ["Object property linking an instance of the class Person to an instance of the class Project."]                                                 
        assigneTo.label = ["Assigne To"]
        class assignedToHim( Project>>Person ): pass
        assignedToHim.comment = ["Object property linking an instance of the class Project to an instance of the class Person."]                                                 
        assignedToHim.label = ["Assigned To Him"]
        assigneTo.inverse_property= assignedToHim
        class isDrivenBy(Project >>Process ): pass
        isDrivenBy.comment = ["Object property linking an instance of the class Project to an instance of the class Process."]                                                 
        isDrivenBy.label = ["Is Driven By"]
        class driven(Process >>Project ): pass
        driven.comment = ["Object property linking an instance of the class Process to an instance of the class Project."]                                                 
        driven.label = ["Driven"]
        isDrivenBy.inverse_property=driven 
        class developmentWayTo(Process >>Product ): pass
        developmentWayTo.comment = ["Object property linking an instance of the class Process to an instance of the class Product."]                                                 
        developmentWayTo.label = ["Development Way To"]
        class hasDevelopment(Product >>Process ): pass
        hasDevelopment.comment = ["Object property linking an instance of the class Product to an instance of the class Process."]                                                 
        hasDevelopment.label = ["Has Development"]
        developmentWayTo.inverse_property=hasDevelopment 
        class workIn(Person >>Company ): pass
        workIn.comment = ["Object property linking an instance of the class Person to an instance of the class Company."]                                                 
        workIn.label = ["Work In"]
        class employed(Company >>Person ): pass
        employed.comment = ["Object property linking an instance of the class Company to an instance of the class Person."]                                                 
        employed.label = ["Employed"]
        workIn.inverse_property=employed
        class isBeingImplementedBy(Project >>Company ): pass
        isBeingImplementedBy.comment = ["Object property linking an instance of the class Project to an instance of the class Company."]                                                 
        isBeingImplementedBy.label = ["Is Being Implemented By"]
        class isImplementing(Company >>Project ): pass
        isImplementing.comment = ["Object property linking an instance of the class Company to an instance of the class Project."]                                                 
        isImplementing.label = ["Is Implementing"]
        isBeingImplementedBy.inverse_property=isImplementing
        class isRegulatedTheirWorkBy(Company >>Policies ): pass
        isRegulatedTheirWorkBy.comment = ["Object property linking an instance of the class Company to an instance of the class Policies."]                                                 
        isRegulatedTheirWorkBy.label = ["Is Regulated Their Work By"]
        class regulateTheWorkOf(Policies>>Company ): pass
        regulateTheWorkOf.comment = ["Object property linking an instance of the class Policies to an instance of the class Company."]                                                 
        regulateTheWorkOf.label = ["Regulate The Work Of"]
        isRegulatedTheirWorkBy.inverse_property=regulateTheWorkOf
 ##person property
        class isFrom(Person >>GeographicalDiversity): pass
        isFrom.comment = ["Object property linking an instance of the class Person to an instance of the class GeographicalDiversity."]                                                 
        isFrom.label = ["Is From"]
        class isTheCountryOf(GeographicalDiversity >>Person ): pass
        isTheCountryOf.comment = ["Object property linking an instance of the class GeographicalDiversity to an instance of the class Person."]                                                 
        isTheCountryOf.label = ["Is The Country Of"]
        isFrom.inverse_property=isTheCountryOf
        class hasTimeDifferent(GeographicalDiversity >>TimeZoneDifferent): pass
        hasTimeDifferent.comment = ["Object property linking an instance of the class GeographicalDiversity to an instance of the class TimeZoneDifferent."]                                                 
        hasTimeDifferent.label = ["Has Time Different"]
        class isATimeDifferentOf(TimeZoneDifferent >>GeographicalDiversity ): pass
        isATimeDifferentOf.comment = ["Object property linking an instance of the class TimeZoneDifferent to an instance of the class GeographicalDiversity."]                                                 
        isATimeDifferentOf.label = ["Is A Time Different Of"]
        hasTimeDifferent.inverse_property=isATimeDifferentOf
        class generate(TimeZoneDifferent >>FollowTheSunApproach ): pass
        generate.comment = ["Object property linking an instance of the class TimeZoneDifferent to an instance of the class FollowTheSunApproach."]                                                 
        generate.label = ["Generate"]
        class isGeneratedBy(FollowTheSunApproach >>TimeZoneDifferent ): pass 
        isGeneratedBycomment = ["Object property linking an instance of the class FollowTheSunApproach to an instance of the class TimeZoneDifferent ."]                                                 
        isGeneratedBy.label = ["Is Generated By"]
        generate.inverse_property=isGeneratedBy
        class resulted(FollowTheSunApproach >>WorkTime ): pass 
        resulted.comment = ["Object property linking an instance of the class FollowTheSunApproach to an instance of the class WorkTime."]                                                 
        resulted.label = ["Resulted"]
        class isResultedBy(WorkTime >>FollowTheSunApproach ): pass
        isResultedBy.comment = ["Object property linking an instance of the class WorkTime to an instance of the class FollowTheSunApproach."]                                                 
        isResultedBy.label = ["Is Resulted By"]
        resulted .inverse_property=isResultedBy
        class use( GeographicalDiversity>>ICTDifferent ): pass
        use.comment = ["Object property linking an instance of the class GeographicalDiversity to an instance of the class ICTDifferent."]                                                 
        use.label = ["Use"]
        class isUsedBy(ICTDifferent>>GeographicalDiversity ): pass 
        isUsedBy.comment = ["Object property linking an instance of the class ICTDifferent to an instance of the class GeographicalDiversity."]                                                 
        isUsedBy.label = ["Is Used By"]
        use .inverse_property=isUsedBy
        class reduce(ICTDifferent >>TravelCostsAndTime ): pass
        reduce.comment = ["Object property linking an instance of the class ICTDifferent to an instance of the class TravelCostsAndTime."]                                                 
        reduce.label = ["Reduce"]
        class isReducedByUsing(TravelCostsAndTime >>ICTDifferent ): pass
        isReducedByUsing.comment = ["Object property linking an instance of the class TravelCostsAndTime to an instance of the class ICTDifferent."]                                                 
        isReducedByUsing.label = ["Is Reduced By Using"]
        reduce.inverse_property=isReducedByUsing
        class enable(ICTDifferent >>WorkFromAnywhereInWorld ): pass
        enable.comment = ["Object property linking an instance of the class ICTDifferent to an instance of the class WorkFromAnywhereInWorld."]                                                 
        enable.label = ["Enable"]
        class isEnabledByUsing(WorkFromAnywhereInWorld >>ICTDifferent ): pass
        isEnabledByUsing.comment = ["Object property linking an instance of the class WorkFromAnywhereInWorld to an instance of the class ICTDifferent."]                                                 
        isEnabledByUsing.label = ["Is Enabled By Using"]
        enable.inverse_property=isEnabledByUsing
        class hasSkill(Person >>DiversityOfSkills ): pass
        hasSkill.comment = ["Object property linking an instance of the class Person to an instance of the class DiversityOfSkills."]                                                 
        hasSkill.label = ["Has Skill"]
        class isASkillOf(DiversityOfSkills >>Person ): pass
        isASkillOf.comment = ["Object property linking an instance of the class DiversityOfSkills to an instance of the class Person."]                                                 
        isASkillOf.label = ["Is A Skill Of"]
        hasSkill.inverse_property=isASkillOf
        class hasCulture(GeographicalDiversity >>CultureDifferences ): pass 
        hasCulture.comment = ["Object property linking an instance of the class GeographicalDiversity to an instance of the class CultureDifferences."]                                                 
        hasCulture.label = ["Has Culture"]
        class isTheCultureOf(CultureDifferences >>GeographicalDiversity ): pass
        isTheCultureOf.comment = ["Object property linking an instance of the class CultureDifferences to an instance of the class GeographicalDiversity."]                                                 
        isTheCultureOf.label = ["Is The Culture Of"]
        hasCulture.inverse_property=isTheCultureOf
        class speak(GeographicalDiversity >>LanguageDifferent ): pass
        speak.comment = ["Object property linking an instance of the class GeographicalDiversity to an instance of the class LanguageDifferent."]                                                 
        speak.label = ["Speak"]
        class isSpokenIn(LanguageDifferent >>GeographicalDiversity ): pass 
        isSpokenIn.comment = ["Object property linking an instance of the class LanguageDifferent to an instance of the class GeographicalDiversity."]                                                 
        isSpokenIn.label = ["Is Spoken In"]
        speak.inverse_property=isSpokenIn
        class belongTo(Person >>Team ): pass
        belongTo.comment = ["Object property linking an instance of the class Person to an instance of the class Team."]                                                 
        belongTo.label = ["Bbelong To"]
        class consistOf(Team >>Person ): pass
        consistOf.comment = ["Object property linking an instance of the class Team to an instance of the class Person."]                                                 
        consistOf.label = ["Consist Of"]
        belongTo.inverse_property=consistOf      
##project property   
        class associateWith( Project >>TaskSets ): pass  
        associateWith.comment = ["Object property linking an instance of the class Project to an instance of the class TaskSets."]                                                 
        associateWith.label = ["Associate With"]
        class linkedTo(TaskSets >> Project): pass
        linkedTo.comment = ["Object property linking an instance of the class TaskSets to an instance of the class Project."]                                                 
        linkedTo.label = ["Linked To"]
        associateWith.inverse_property=linkedTo 
        class identifies( TaskSets >>WorkTasks ): pass 
        identifies.comment = ["Object property linking an instance of the class TaskSets to an instance of the class WorkTasks."]                                                 
        identifies.label = ["Identifies"]
        class isIdentifiedBy(WorkTasks >> TaskSets): pass
        isIdentifiedBy.comment = ["Object property linking an instance of the class WorkTasks to an instance of the class TaskSets."]                                                 
        isIdentifiedBy.label = ["Is Identified By"]
        identifies.inverse_property=isIdentifiedBy 
        class arePerformedBy(WorkTasks >>Team ): pass
        arePerformedBy.comment = ["Object property linking an instance of the class WorkTasks to an instance of the class Team."]                                                 
        arePerformedBy.label = ["Are Performed By"]
        class performs(Team >>WorkTasks ): pass  
        performs.comment = ["Object property linking an instance of the class Team to an instance of the class WorkTasks."]                                                 
        performs.label = ["Performs"]
        arePerformedBy.inverse_property=performs 
        class isCommunicatedBy(Team >> ICTDifferent ): pass
        isCommunicatedBy.comment = ["Object property linking an instance of the class Team to an instance of the class ICTDifferent."]                                                 
        isCommunicatedBy.label = ["Is Communicated By"]
        class isACommunicationToolTo( ICTDifferent>>Team ): pass
        isACommunicationToolTo.comment = ["Object property linking an instance of the class ICTDifferent to an instance of the class Team."]                                                 
        isACommunicationToolTo.label = ["Is A Communication Tool To"]
        isCommunicatedBy.inverse_property=isACommunicationToolTo 
        class hasFts(Team >> FollowTheSunApproach ): pass
        hasFts.comment = ["Object property linking an instance of the class Team to an instance of the class FollowTheSunApproach."]                                                 
        hasFts.label = ["Has Fts"]
        class isFtsOf( FollowTheSunApproach>>Team ): pass
        isFtsOf.comment = ["Object property linking an instance of the class FollowTheSunApproach to an instance of the class Team."]                                                 
        isFtsOf.label = ["Is Fts Of"]
        hasFts.inverse_property=isFtsOf  
        class isCommunicateIn(Team >>Communication ): pass
        isCommunicateIn.comment = ["Object property linking an instance of the class Team to an instance of the class Communication."]                                                 
        isCommunicateIn.label = ["Is Communicate In"]
        class isACommunicationWayIn(Communication >>Team ): pass 
        isACommunicationWayIn.comment = ["Object property linking an instance of the class Communication to an instance of the class Team."]                                                 
        isACommunicationWayIn.label = ["Is A Communication Way In"]
        isCommunicateIn.inverse_property=isACommunicationWayIn 
        class isDirectedBy(Team >>Leadership ): pass 
        isDirectedBy.comment = ["Object property linking an instance of the class Team to an instance of the class Leadership."]                                                 
        isDirectedBy.label = ["Is Directed By"]
        class isLeaderOf(Leadership >>Team ): pass  
        isLeaderOf.comment = ["Object property linking an instance of the class Leadership to an instance of the class Team."]                                                 
        isLeaderOf.label = ["Is Leader Of"]
        isDirectedBy.inverse_property=isLeaderOf 
        class cooperateThrough(Team >>Cooperation ): pass 
        cooperateThrough.comment = ["Object property linking an instance of the class Team to an instance of the class Cooperation."]                                                 
        cooperateThrough.label = ["CooperateThrough"]
        class isCooperatedWayOf(Cooperation >>Team ): pass
        isCooperatedWayOf.comment = ["Object property linking an instance of the class Cooperation to an instance of the class Team."]                                                 
        isCooperatedWayOf.label = ["Is Cooperated Way Of"]
        cooperateThrough.inverse_property=isCooperatedWayOf 
        class mustHaveATypeOf(Team >>Coordination ): pass
        mustHaveATypeOf.comment = ["Object property linking an instance of the class Team to an instance of the class Coordination."]                                                 
        mustHaveATypeOf.label = ["Must Have A Type Of"]
        class isATypeOfCoordinationIn(Coordination >>Team): pass 
        isATypeOfCoordinationIn.comment = ["Object property linking an instance of the class Coordination to an instance of the class Team."]                                                 
        isATypeOfCoordinationIn.label = ["Is A Type Of Coordination In"]
        mustHaveATypeOf.inverse_property=isATypeOfCoordinationIn 
        class needsToBuild(Team >>Trust ): pass
        needsToBuild.comment = ["Object property linking an instance of the class Team to an instance of the class Trust."]                                                 
        needsToBuild.label = ["Needs To Build"]
        class increasesCollaborationIn(Trust >>Team ): pass  
        increasesCollaborationIn.comment = ["Object property linking an instance of the class Trust to an instance of the class Team."]                                                 
        increasesCollaborationIn.label = ["Increases Collaboration In"]
        needsToBuild.inverse_property=increasesCollaborationIn 
        class isCohesiveWhen(Team >> Cohesion): pass
        isCohesiveWhen.comment = ["Object property linking an instance of the class Team to an instance of the class Cohesion."]                                                 
        isCohesiveWhen.label = ["Is Cohesive When"]
        class isACohesionFactor(Cohesion >>Team ): pass   
        isACohesionFactor.comment = ["Object property linking an instance of the class Cohesion to an instance of the class Team."]                                                 
        isACohesionFactor.label = ["Is A Cohesion Factor"]
        isCohesiveWhen.inverse_property=isACohesionFactor 
        class performanceIncreasesWith(Team >>KnowledgeSharing ): pass 
        performanceIncreasesWith.comment = ["Object property linking an instance of the class Team to an instance of the class KnowledgeSharing."]                                                 
        performanceIncreasesWith.label = ["Performance Increases With"]
        class isATypeOfKnowledgeIn(KnowledgeSharing >>Team ): pass
        isATypeOfKnowledgeIn.comment = ["Object property linking an instance of the class KnowledgeSharing to an instance of the class Team."]                                                 
        isATypeOfKnowledgeIn.label = ["Is A Type Of Knowledge In"]
        performanceIncreasesWith.inverse_property=isATypeOfKnowledgeIn 
        class hasMotivation(Team >>Motivation ): pass 
        hasMotivation.comment = ["Object property linking an instance of the class Team to an instance of the class Motivation."]                                                 
        hasMotivation.label = ["Has Motivation"]
        class isAMotivationWayTo(Motivation >>Team ): pass 
        isAMotivationWayTo.comment = ["Object property linking an instance of the class Motivation to an instance of the class Team."]                                                 
        isAMotivationWayTo.label = ["Is A Motivation Way To"]
        hasMotivation.inverse_property=isAMotivationWayTo 
        class isSplitedBy(Team >> Conflict): pass
        isSplitedBy.comment = ["Object property linking an instance of the class Team to an instance of the class Conflict."]                                                 
        isSplitedBy.label = ["Is Splited By"]
        class split(Conflict >>Team ): pass  
        split.comment = ["Object property linking an instance of the class Conflict to an instance of the class Team."]                                                 
        split.label = ["Split"]
        isSplitedBy.inverse_property=split
        class isWeakenBy(Team >> StaffTurnover): pass
        isWeakenBy.comment = ["Object property linking an instance of the class Team to an instance of the class StaffTurnover."]                                                 
        isWeakenBy.label = ["Is Weaken By"]
        class weaken(StaffTurnover >>Team ): pass  
        isWeakenBy.inverse_property=weaken
        weaken.comment = ["Object property linking an instance of the class StaffTurnover to an instance of the class Team."]                                                 
        weaken.label = ["Weaken"]
        class mustTakeInformationFrom(Team >>ReliabilityOfInformation ): pass
        mustTakeInformationFrom.comment = ["Object property linking an instance of the class Team to an instance of the class ReliabilityOfInformation."]                                                 
        mustTakeInformationFrom.label = ["Must Take Information From"]
        class providesReliableInformationTo(ReliabilityOfInformation >>Team ): pass
        providesReliableInformationTo.comment = ["Object property linking an instance of the class ReliabilityOfInformation to an instance of the class Team."]                                                 
        providesReliableInformationTo.label = ["Provides Reliable Information To"]
        providesReliableInformationTo.inverse_property=mustTakeInformationFrom
        class savesDataIn(Team>>DataRepositories ): pass
        savesDataIn.comment = ["Object property linking an instance of the class Team to an instance of the class DataRepositories."]                                                 
        savesDataIn.label = ["Saves Data In"]
        class facilitateAccessToInformationIn(DataRepositories >>Team ): pass
        savesDataIn.inverse_property=facilitateAccessToInformationIn        
        facilitateAccessToInformationIn.comment = ["Object property linking an instance of the class DataRepositories to an instance of the class Team."]                                                 
        facilitateAccessToInformationIn.label = ["Facilitate Access To Information In"]
        class needInWorkTo(Team >>ComfortEnvironment ): pass
        needInWorkTo.comment = ["Object property linking an instance of the class Team to an instance of the class ComfortEnvironment."]                                                 
        needInWorkTo.label = ["Need In Work To"]
        class haveAGreatImpactTo(ComfortEnvironment >>Team ): pass   
        haveAGreatImpactTo.comment = ["Object property linking an instance of the class ComfortEnvironment to an instance of the class Team."]                                                 
        haveAGreatImpactTo.label = ["Have A Great Impact To"]
        haveAGreatImpactTo.inverse_property= needInWorkTo
        class isFacing(Team >>TechnicalProblems ): pass      
        isFacing.comment = ["Object property linking an instance of the class Team to an instance of the class TechnicalProblems."]                                                 
        isFacing.label = ["Is Facing"]
        class decreasedPerformance(TechnicalProblems >>Team): pass 
        isFacing.inverse_property=decreasedPerformance 
        decreasedPerformance.comment = ["Object property linking an instance of the class TechnicalProblems to an instance of the class Team."]
        decreasedPerformance.label = ["Decreased Performance"]
        class isFrustratedBy(Team >>LackOfOrganizationalStructure ): pass
        isFrustratedBy.comment = ["Object property linking an instance of the class Team to an instance of the class LackOfOrganizationalStructure."]                                                 
        isFrustratedBy.label = ["Is Frustrated By"]
        class frustrate(LackOfOrganizationalStructure >>Team ): pass  
        isFrustratedBy.inverse_property= frustrate
        frustrate.comment = ["Object property linking an instance of the class LackOfOrganizationalStructure to an instance of the class Team."]                                                 
        frustrate.label = ["Frustrate"]
        class need(Team >>Training ): pass 
        need.comment = ["Object property linking an instance of the class Team to an instance of the class Training."]                                                 
        need.label = ["Need"]
        class isIncreasingEfficiencyOf( Training>>Team ): pass 
        need.inverse_property=isIncreasingEfficiencyOf 
        isIncreasingEfficiencyOf.comment = ["Object property linking an instance of the class Training to an instance of the class Team."]                                                 
        isIncreasingEfficiencyOf.label = ["Is Increasing Efficiency Of"]
        class add(Training >>Experience ): pass
        add.comment = ["Object property linking an instance of the class Training to an instance of the class Experience."]                                                 
        add.label = ["Add"]
        class isAddedBy(Experience >>Training ): pass
        add.inverse_property=isAddedBy 
        isAddedBy.comment = ["Object property linking an instance of the class Experience to an instance of the class Training."]                                                 
        isAddedBy.label = ["Is Added By"]
        class hasSize(Team >>TeamSize ): pass 
        hasSize.comment = ["Object property linking an instance of the class Team to an instance of the class TeamSize."]                                                 
        hasSize.label = ["Has Size"]
        class isTheSizeOf(TeamSize >>Team  ): pass    
        hasSize.inverse_property=isTheSizeOf    
        isTheSizeOf.comment = ["Object property linking an instance of the class TeamSize to an instance of the class Team."]                                                 
        isTheSizeOf.label = ["Is The Size Of"]
        class impactOn(TeamSize >>FactorsImpactedbySize): pass  
        impactOn.comment = ["Object property linking an instance of the class TeamSize to an instance of the class FactorsImpactedbySize."]                                                 
        impactOn.label = ["Impact On"]
        class isImpactedBy(FactorsImpactedbySize  >>TeamSize  ): pass
        impactOn.inverse_property=isImpactedBy                 
        isImpactedBy.comment = ["Object property linking an instance of the class FactorsImpactedbySize to an instance of the class TeamSize."]                                                 
        isImpactedBy.label = ["Is Impacted By"]
        class increasesPerformanceThrough(Team >>Teamness ): pass 
        increasesPerformanceThrough.comment = ["Object property linking an instance of the class Team to an instance of the class Teamness."]                                                 
        increasesPerformanceThrough.label = ["Increases Performance Through"]
        class improvesPerformanceOf(Teamness >>Team ): pass
        increasesPerformanceThrough.inverse_property=improvesPerformanceOf
        improvesPerformanceOf.comment = ["Object property linking an instance of the class Teamness to an instance of the class Team."]                                                 
        improvesPerformanceOf.label = ["Improves Performance Of"]
##process property
        class isRelatedTo(Process >>DocumentationProblems ): pass
        isRelatedTo.comment = ["Object property linking an instance of the class Process to an instance of the class DocumentationProblems."]                                                 
        isRelatedTo.label = ["Is Related To"]
        class isSelectedByOneOf(Process >>Team ): pass 
        isSelectedByOneOf.comment = ["Object property linking an instance of the class Process to an instance of the class Team."]                                                 
        isSelectedByOneOf.label = ["Is Selected By One Of"]
        class selectedOneOf(Team >> Process): pass 
        isSelectedByOneOf.inverse_property=selectedOneOf
        selectedOneOf.comment = ["Object property linking an instance of the class Team to an instance of the class Process."]                                                 
        selectedOneOf.label = ["Selected One Of"]
        class hasFramework(Process  >>ProcessFramework ):pass 
        hasFramework.comment = ["Object property linking an instance of the class Process to an instance of the class ProcessFramework."]                                                 
        hasFramework.label = ["Has Framework"]
        class isAFrameworkOf(ProcessFramework>>Process ): pass
        hasFramework.inverse_property=isAFrameworkOf
        isAFrameworkOf.comment = ["Object property linking an instance of the class ProcessFramework to an instance of the class Process."]                                                 
        isAFrameworkOf.label = ["Is A Framework Of"]
        class hasActivities(ProcessFramework >>FrameworkActivities ): pass
        hasActivities.comment = ["Object property linking an instance of the class ProcessFramework to an instance of the class FrameworkActivities."]                                                 
        hasActivities.label = ["Has Activities"]
        class isAnActivityOf(FrameworkActivities >>ProcessFramework ): pass
        hasActivities.inverse_property=isAnActivityOf
        isAnActivityOf.comment = ["Object property linking an instance of the class FrameworkActivities to an instance of the class ProcessFramework."]                                                 
        isAnActivityOf.label = ["Is An Activity Of"]
        class mustAppropriate(Process >>MarketplaceDemands ): pass
        mustAppropriate.comment = ["Object property linking an instance of the class Process to an instance of the class MarketplaceDemands."]                                                 
        mustAppropriate.label = ["Must Appropriate"]
        class forceTheUseOneOf(MarketplaceDemands >>Process ): pass
        mustAppropriate.inverse_property=forceTheUseOneOf
        forceTheUseOneOf.comment = ["Object property linking an instance of the class MarketplaceDemands to an instance of the class Process."]                                                 
        forceTheUseOneOf.label = ["Force The Use One Of"]
        class isResulted(MarketplaceDemands >>RequirementProblem ): pass
        isResulted.comment = ["Object property linking an instance of the class MarketplaceDemands to an instance of the class RequirementProblem."]                                                 
        isResulted.label = ["Is Resulted"]
        class isAResultOf(RequirementProblem >>MarketplaceDemands ): pass 
        isResulted.inverse_property=isAResultOf
        isAResultOf.comment = ["Object property linking an instance of the class RequirementProblem to an instance of the class MarketplaceDemands."]                                                 
        isAResultOf.label = ["Is A Result Of"]
        class leadTo(RequirementProblem >> DesignProblems): pass
        leadTo.comment = ["Object property linking an instance of the class RequirementProblem to an instance of the class DesignProblems."]                                                 
        leadTo.label = ["Lead To"]
        class suffersFrom(FrameworkActivities >>RequirementProblem ): pass
        suffersFrom.comment = ["Object property linking an instance of the class FrameworkActivities to an instance of the class RequirementProblem."]                                                 
        suffersFrom.label = ["Suffers From"]
        class isAProblemAffects(RequirementProblem >>FrameworkActivities ): pass 
        suffersFrom.inverse_property=isAProblemAffects
        isAProblemAffects.comment = ["Object property linking an instance of the class RequirementProblem to an instance of the class FrameworkActivities."]                                                 
        isAProblemAffects.label = ["Is A Problem Affects"]
        class hasPrinciples(FrameworkActivities >>FrameworkActivitiesPrinciples ): pass 
        hasPrinciples.comment = ["Object property linking an instance of the class FrameworkActivities to an instance of the class FrameworkActivitiesPrinciples."]                                                 
        hasPrinciples.label = ["Has Principles"]
        class isAPrinciplesOf(FrameworkActivitiesPrinciples >>FrameworkActivities ): pass  
        hasPrinciples.inverse_property=isAPrinciplesOf
        isAPrinciplesOf.comment = ["Object property linking an instance of the class FrameworkActivitiesPrinciples to an instance of the class FrameworkActivities."]                                                 
        isAPrinciplesOf.label = ["Is A Principles Of"]
        class notUsedCause(FrameworkActivitiesPrinciples >> DesignProblems ): pass
        notUsedCause.comment = ["Object property linking an instance of the class FrameworkActivitiesPrinciples to an instance of the class DesignProblems."]                                                 
        notUsedCause.label = ["Not Used Cause"]
        class isCausedByNotUsed(DesignProblems >> FrameworkActivitiesPrinciples ): pass 
        notUsedCause.inverse_property=isCausedByNotUsed
        isCausedByNotUsed.comment = ["Object property linking an instance of the class DesignProblems to an instance of the class FrameworkActivitiesPrinciples."]                                                 
        isCausedByNotUsed.label = ["Is Caused By Not Used"]
        class notUsedReason(FrameworkActivitiesPrinciples >>CodingProblems): pass
        notUsedReason.comment = ["Object property linking an instance of the class FrameworkActivitiesPrinciples to an instance of the class CodingProblems."]                                                 
        notUsedReason.label = ["Not Used Reason"]
        class isReasonedByNotUsed(CodingProblems  >> FrameworkActivitiesPrinciples ): pass 
        notUsedReason.inverse_property=isReasonedByNotUsed
        isReasonedByNotUsed.comment = ["Object property linking an instance of the class CodingProblems to an instance of the class FrameworkActivitiesPrinciples."]                                                 
        isReasonedByNotUsed.label = ["Is Reasoned By Not Used"]
        class notUsedOccasion(FrameworkActivitiesPrinciples >>DocumentationProblems ): pass
        notUsedOccasion.comment = ["Object property linking an instance of the class FrameworkActivitiesPrinciples to an instance of the class DocumentationProblems."]                                                 
        notUsedOccasion.label = ["Not Used Occasion"]
        class isOccasionedByNotUsed(DocumentationProblems >>FrameworkActivitiesPrinciples ): pass 
        notUsedOccasion.inverse_property=isOccasionedByNotUsed  
        isOccasionedByNotUsed.comment = ["Object property linking an instance of the class DocumentationProblems to an instance of the class FrameworkActivitiesPrinciples."]                                                 
        isOccasionedByNotUsed.label = ["Is Occasioned By Not Used"]
        class evolveInto(DesignProblems >>CodingProblems ): pass 
        evolveInto.comment = ["Object property linking an instance of the class DesignProblems to an instance of the class CodingProblems."]                                                 
        evolveInto.label = ["Evolve Into"]
        class shiftInto(CodingProblems>>DocumentationProblems ): pass       
        shiftInto.comment = ["Object property linking an instance of the class CodingProblems to an instance of the class DocumentationProblems."]                                                 
        shiftInto.label = ["Shift Into"]
        class turnInto(DesignProblems >>TestingAndMaintenanceDifficult): pass
        turnInto.comment = ["Object property linking an instance of the class DesignProblems to an instance of the class TestingAndMaintenanceDifficult."]                                                 
        turnInto.label = ["Turn Into"]
        class isPerhapsA(TestingAndMaintenanceDifficult >>DesignProblems): pass
        turnInto.inverse_property=isPerhapsA          
        isPerhapsA.comment = ["Object property linking an instance of the class TestingAndMaintenanceDifficult to an instance of the class DesignProblems."]                                                 
        isPerhapsA.label = ["Is Perhaps A"]
        class convertedTo( CodingProblems >> TestingAndMaintenanceDifficult): pass
        convertedTo.comment = ["Object property linking an instance of the class CodingProblems to an instance of the class TestingAndMaintenanceDifficult."]                                                 
        convertedTo.label = ["Converted To"]
        class isPossiblyA(TestingAndMaintenanceDifficult >>CodingProblems ): pass
        convertedTo.inverse_property=isPossiblyA
        isPossiblyA.comment = ["Object property linking an instance of the class TestingAndMaintenanceDifficult to an instance of the class CodingProblems."]                                                 
        isPossiblyA.label = ["Is Possibly A"]
        class changedTo(DocumentationProblems >> TestingAndMaintenanceDifficult): pass
        changedTo.comment = ["Object property linking an instance of the class DocumentationProblems to an instance of the class TestingAndMaintenanceDifficult."]                                                 
        changedTo.label = ["Changed To"]
        class isLikelyA(TestingAndMaintenanceDifficult >> DocumentationProblems ): pass
        changedTo.inverse_property=isLikelyA               
        isLikelyA.comment = ["Object property linking an instance of the class TestingAndMaintenanceDifficult to an instance of the class DocumentationProblems."]                                                 
        isLikelyA.label = ["Is Likely A"]
        class maybeTranslateTo(DocumentationProblems >>RequirementsNotUnderstood ): pass 
        maybeTranslateTo.comment = ["Object property linking an instance of the class DocumentationProblems to an instance of the class RequirementsNotUnderstood."]                                                 
        maybeTranslateTo.label = ["Maybe Translate To"]
        
##product property
        class hasGoal(Product >>Goal ): pass
        hasGoal.comment = ["Object property linking an instance of the class Product to an instance of the class Goal."]                                                 
        hasGoal.label = ["Has Goal"]
        class isAGoalOf(Goal >>Product ): pass 
        hasGoal.inverse_property=isAGoalOf
        isAGoalOf.comment = ["Object property linking an instance of the class Goal to an instance of the class Product."]                                                 
        isAGoalOf.label = ["Is A Goal Of"]
        class hasScope(Product >>Scope ): pass 
        hasScope.comment = ["Object property linking an instance of the class Product to an instance of the class Scope."]                                                 
        hasScope.label = ["Has Scope"]
        class isAScopeOf(Scope >>Product ): pass 
        hasScope.inverse_property=isAScopeOf
        isAScopeOf.comment = ["Object property linking an instance of the class Scope to an instance of the class Product."]                                                 
        isAScopeOf.label = ["Is A Scope Of"]
        class hasCost(Product >>Cost ): pass 
        hasCost.comment = ["Object property linking an instance of the class Product to an instance of the class Cost."]                                                 
        hasCost.label = ["Has Cost"]
        class isACostOf(Cost >>Product ): pass 
        hasCost.inverse_property=isACostOf
        isACostOf.comment = ["Object property linking an instance of the class Cost to an instance of the class Product."]                                                 
        isACostOf.label = ["Is A Cost Of"]
        class isDecreasedBy(Cost >>GoalOfProximityToHumanResources ): pass
        isDecreasedBy.comment = ["Object property linking an instance of the class Cost to an instance of the class GoalOfProximityToHumanResources."]                                                 
        isDecreasedBy.label = ["Is Decreased By"]
        class decrease( GoalOfProximityToHumanResources>>Cost ): pass 
        isDecreasedBy.inverse_property=decrease
        decrease.comment = ["Object property linking an instance of the class GoalOfProximityToHumanResources to an instance of the class Cost."]                                                 
        decrease.label = ["Decrease"]
        class hasTime(Product >>Time ): pass 
        hasTime.comment = ["Object property linking an instance of the class Product to an instance of the class Time."]                                                 
        hasTime.label = ["Has Time"]
        class isATimeOf(Time >>Product ): pass 
        hasTime.inverse_property=isATimeOf
        isATimeOf.comment = ["Object property linking an instance of the class Time to an instance of the class Product."]                                                 
        isATimeOf.label = ["Is A Time Of"]
        class isScheduledAccordingTo(Time >>WorkTasksScheduling ): pass 
        isScheduledAccordingTo.comment = ["Object property linking an instance of the class Time to an instance of the class WorkTasksScheduling."]                                                 
        isScheduledAccordingTo.label = ["Is Scheduled According To"]
        class hasQuality(Product >>Quality ): pass 
        hasQuality.comment = ["Object property linking an instance of the class Product to an instance of the class Quality."]                                                 
        hasQuality.label = ["Has Quality"]
        class isAQualityOf(Quality >>Product ): pass
        hasQuality.inverse_property=isAQualityOf
        isAQualityOf.comment = ["Object property linking an instance of the class Quality to an instance of the class Product."]                                                 
        isAQualityOf.label = ["Is A Quality Of"]
        class dependsOn(Quality >>QualityFactors ): pass  
        dependsOn.comment = ["Object property linking an instance of the class Quality to an instance of the class QualityFactors."]                                                 
        dependsOn.label = ["Depends On"]
        class isRepresentedBy(QualityFactors >>Quality ): pass 
        dependsOn.inverse_property=isRepresentedBy
        isRepresentedBy.comment = ["Object property linking an instance of the class QualityFactors to an instance of the class Quality."]                                                 
        isRepresentedBy.label = ["Is Represented By"]
        class becomesComplicateIn(Quality >>NewnessTechnology ): pass 
        becomesComplicateIn.comment = ["Object property linking an instance of the class Quality to an instance of the class NewnessTechnology."]                                                 
        becomesComplicateIn.label = ["Becomes Complicate In"]
        class complicatesAchieving(NewnessTechnology >>Quality ): pass  
        becomesComplicateIn.inverse_property=complicatesAchieving
        complicatesAchieving.comment = ["Object property linking an instance of the class NewnessTechnology to an instance of the class Quality."]                                                 
        complicatesAchieving.label = ["Complicates Achieving"]
        class isIncreasedBy(Quality >>StakeholderParticipationEarly): pass
        isIncreasedBy.comment = ["Object property linking an instance of the class Quality to an instance of the class StakeholderParticipationEarly."]                                                 
        isIncreasedBy.label = ["Is Increased By"]
        class increases(StakeholderParticipationEarly>>Quality): pass
        isIncreasedBy.inverse_property=increases
        increases.comment = ["Object property linking an instance of the class StakeholderParticipationEarly to an instance of the class Quality."]                                                 
        increases.label = ["Increases"]
        class isGoDownBy(Quality >>SWComplexity ): pass 
        isGoDownBy.comment = ["Object property linking an instance of the class Quality to an instance of the class SWComplexity."]                                                 
        isGoDownBy.label = ["Is Go Down By"]
        class goDown(SWComplexity >> Quality): pass 
        isGoDownBy.inverse_property=goDown
        goDown.comment = ["Object property linking an instance of the class SWComplexity to an instance of the class Quality."]                                                 
        goDown.label = ["Go Down"]
        class isDeterminedBy(SWComplexity >>SWSize): pass
        isDeterminedBy.comment = ["Object property linking an instance of the class SWComplexity to an instance of the class SWSize."]                                                 
        isDeterminedBy.label = ["Is Determined By"]
        class determines(SWSize >>SWComplexity ): pass
        isDeterminedBy.inverse_property=determines
        determines.comment = ["Object property linking an instance of the class SWSize to an instance of the class SWComplexity."]                                                 
        determines.label = ["Determines"]
        class areAllocatedBy(Resources >>Product ): pass        
        areAllocatedBy.comment = ["Object property linking an instance of the class Resources to an instance of the class Product."]                                                 
        areAllocatedBy.label = ["Are Allocated By"]
        class needsToAllocate(Product >>Resources ): pass 
        areAllocatedBy.inverse_property=needsToAllocate
        needsToAllocate.comment = ["Object property linking an instance of the class Product to an instance of the class Resources."]                                                 
        needsToAllocate.label = ["Needs To Allocate"]

# %%
a=list(onto.object_properties())
print(len (a))

list(onto.object_properties())
# Out:
# 150
# [GvtOntoInGsd.isAffectedFirstlyBy,
#  GvtOntoInGsd.isTheFirstEffectOn,
#  GvtOntoInGsd.isAffectedSecondlyBy,
#  GvtOntoInGsd.isTheSecondEffectOn,
#  GvtOntoInGsd.isAffectedThirdlyBy,
#  GvtOntoInGsd.isTheThirdEffectOn,
#  GvtOntoInGsd.isAffectedFourthlyBy,
#  GvtOntoInGsd.isTheFourthEffectOn,
#  GvtOntoInGsd.isADeveloperFor,
#  GvtOntoInGsd.isDevelopedBy,
#  GvtOntoInGsd.assigneTo,
#  GvtOntoInGsd.assignedToHim,
#  GvtOntoInGsd.isDrivenBy,
#  GvtOntoInGsd.driven,
#  GvtOntoInGsd.developmentWayTo,
#  GvtOntoInGsd.hasDevelopment,
#  GvtOntoInGsd.workIn,
#  GvtOntoInGsd.employed,
#  GvtOntoInGsd.isBeingImplementedBy,
#  GvtOntoInGsd.isImplementing,
#  GvtOntoInGsd.isRegulatedTheirWorkBy,
#  GvtOntoInGsd.regulateTheWorkOf,
#  GvtOntoInGsd.isFrom,
#  GvtOntoInGsd.isTheCountryOf,
#  GvtOntoInGsd.hasTimeDifferent,
#  GvtOntoInGsd.isATimeDifferentOf,
#  GvtOntoInGsd.generate,
#  GvtOntoInGsd.isGeneratedBy,
#  GvtOntoInGsd.resulted,
#  GvtOntoInGsd.isResultedBy,
#  GvtOntoInGsd.use,
# ...

# %% [markdown]
# # Creating Data properties

# %%
with onto:

    class goalIsUnclear(DataProperty):
                domain = [Goal]
                range  = [bool]
    goalIsUnclear.comment = ["Data property represents the clarity of the product goal in boolean form."]                                                 
    goalIsUnclear.label = ["Goal Is Unclear"]            
    class scopeIsUnclear(DataProperty):
               domain = [Scope]
               range  = [bool]
    scopeIsUnclear.comment = ["Data property represents the clarity of the product scope in boolean form."]                                                 
    scopeIsUnclear.label = ["Scope Is Unclear"]
    class timeAllocation(DataProperty):
               domain = [WorkTasksScheduling ]
               range  = [str]
    timeAllocation.comment = ["Data property represents the time allocated to the task in days."]                                                 
    timeAllocation.label = ["Time Allocation"]
    class effortAllocation(DataProperty):
              domain = [WorkTasksScheduling]
              range  = [str]
    effortAllocation.comment = ["Data property represents the effort allocated to the task in person/day."]                                                 
    effortAllocation.label = ["Effort Allocation"]
    class effortValidation(DataProperty):
              domain = [WorkTasksScheduling]
              range  = [str]
    effortValidation.comment = ["Data property represents the validation of the effort allocated to the task in string form yes or no ."]                                                 
    effortValidation.label = ["Effort Validation"]          
                
    class definedResponsibilities(DataProperty):
              domain = [WorkTasksScheduling]
              range = [str]
            
    definedResponsibilities.comment = ["Data property represents the persons selected to perform the tasks."]                                                 
    definedResponsibilities.label = ["Defined Responsibilities"]
    class deliveryDeadline(DataProperty):
            domain = [WorkTasksScheduling]
            range = [str]
            
    deliveryDeadline.comment = ["Data property represents delivery deadline of the product in string form eg. week1_day2."]                                                 
    deliveryDeadline.label = ["Delivery Deadline"]
#******************************************    
    class firstName(DataProperty):
                domain = [Person]
                range  = [str] 
    
    firstName.comment = ["Data property represents the first name of a person."]                                                 
    firstName.label = ["First Name"]
    
    
    class age(DataProperty):
               domain = [Person]
               range  = [int]
    age.comment = ["Data property represents the age of person in years ."]                                                 
    age.label = ["Age"]            
    
    class birthday(DataProperty):
            domain = [Person ]
            range  = [str]
           
    birthday.comment = ["Data property represents the  birthday of the person represented in dd-mm-yy string form, eg. 13-2-1985."]                                                 
    birthday.label = ["Birthday"]        
    class gender(DataProperty):
              domain = [Person]
              range  = [str]
                
    gender.comment = ["Data property represents the gender of the person ( male or female)."]                                                 
    gender.label = ["Gender"]
    class account(DataProperty):
              domain = [Person]
              range  = [str]
    account.comment = ["Data property represents the name of the online account of the person"]                                                 
    account.label = ["Account"]
    class yearOfExperience(DataProperty):
              domain = [Person]
              range = [str]
    yearOfExperience.comment = ["Data property represents the years of experience of the person in month."]                                                 
    yearOfExperience.label = ["Year Of Experience"]

# %%
list(onto.data_properties())
# Out:
# [GvtOntoInGsd.goalIsUnclear,
#  GvtOntoInGsd.scopeIsUnclear,
#  GvtOntoInGsd.timeAllocation,
#  GvtOntoInGsd.effortAllocation,
#  GvtOntoInGsd.effortValidation,
#  GvtOntoInGsd.definedResponsibilities,
#  GvtOntoInGsd.deliveryDeadline,
#  GvtOntoInGsd.firstName,
#  GvtOntoInGsd.age,
#  GvtOntoInGsd.birthday,
#  GvtOntoInGsd.gender,
#  GvtOntoInGsd.account,
#  GvtOntoInGsd.yearOfExperience]

# %% [markdown]
# # Creating restrictions

# %%
GVTPerformanceInGSD.is_a.append(isAffectedFirstlyBy.some(Person))
GVTPerformanceInGSD.is_a.append(isAffectedSecondlyBy.some(Project))
Project.is_a.append(isTheSecondEffectOn.some(GVTPerformanceInGSD))
GVTPerformanceInGSD.is_a.append(isAffectedThirdlyBy.some(Process))
Process.is_a.append(isTheThirdEffectOn.some(GVTPerformanceInGSD))
GVTPerformanceInGSD.is_a.append(isAffectedFourthlyBy.some(Product))
Person.is_a.append(isADeveloperFor.some(Product))
Product.is_a.append(isDevelopedBy.some(Person))
Person.is_a.append(assigneTo.some(Project))
Project.is_a.append(assignedToHim.some(Person))

 
Project.is_a.append(isDrivenBy.exactly(1,Process)) 
Project.is_a.append(isDrivenBy.some(Process))

Product.is_a.append(hasDevelopment.exactly(1,Process)) 
Product.is_a.append(hasDevelopment.some(Process))
Person.is_a.append(workIn.exactly(1,Company))
Person.is_a.append(workIn.some(Company))
Company.is_a.append(employed.some(Person))

Project.is_a.append(isBeingImplementedBy.some(Company))
Company.is_a.append(isImplementing.some(Project))

Company.is_a.append(isRegulatedTheirWorkBy.some(Policies))


#Person restrictions
Person.is_a.append(belongTo.some(Team))
Team.is_a.append(consistOf.some(Person))
Person.is_a.append(hasSkill.some(DiversityOfSkills))
Person.is_a.append(isFrom.exactly(1,GeographicalDiversity))
Person.is_a.append(isFrom.some(GeographicalDiversity))
GeographicalDiversity.is_a.append(isTheCountryOf.some(Person))                               
GeographicalDiversity.is_a.append(speak.some(LanguageDifferent))
GeographicalDiversity.is_a.append(hasCulture.some(CultureDifferences))
CultureDifferences.is_a.append(isTheCultureOf.some(GeographicalDiversity))
GeographicalDiversity.is_a.append(use.some(ICTDifferent))
ICTDifferent.is_a.append(Asynchronous|Synchronous)
ICTDifferent.is_a.append(reduce.some(TravelCostsAndTime))
TravelCostsAndTime.is_a.append(isReducedByUsing.some(ICTDifferent))
ICTDifferent.is_a.append(enable.some(WorkFromAnywhereInWorld))
WorkFromAnywhereInWorld.is_a.append(isEnabledByUsing.some(ICTDifferent))

GeographicalDiversity.is_a.append(hasTimeDifferent.exactly(1,TimeZoneDifferent))
TimeZoneDifferent.is_a.append(isATimeDifferentOf.exactly(1,GeographicalDiversity))
GeographicalDiversity.is_a.append(hasTimeDifferent.some(TimeZoneDifferent))
TimeZoneDifferent.is_a.append(isATimeDifferentOf.some(GeographicalDiversity))
                            
TimeZoneDifferent.is_a.append(generate.some(FollowTheSunApproach))                              
FollowTheSunApproach.is_a.append(isGeneratedBy.some(TimeZoneDifferent))                              
FollowTheSunApproach.is_a.append(resulted.exactly(1,WorkTime))
FollowTheSunApproach.is_a.append(resulted.some(WorkTime))                                                                                     
FollowTheSunApproach.is_a.append(isFtsOf.exactly(1,Team))
Team.is_a.append(hasFts.exactly(1,FollowTheSunApproach))                             
FollowTheSunApproach.is_a.append(isFtsOf.some(Team))
Team.is_a.append(hasFts.some(FollowTheSunApproach))   


Person.is_a.append(firstName.exactly(1,str))
Person.is_a.append(firstName.some(str))
Person.is_a.append(age.exactly(1,int))
Person.is_a.append(age.some(int))
Person.is_a.append(birthday.exactly(1,str))
Person.is_a.append(birthday.some(str))
Person.is_a.append(gender.exactly(1,str))
Person.is_a.append(gender.some(str))
Person.is_a.append(account.some(str))
Person.is_a.append(yearOfExperience.exactly(1,str))
Person.is_a.append(yearOfExperience.some(str))

#Project restrictions

Project.is_a.append(associateWith.exactly(1,TaskSets))
TaskSets.is_a.append(linkedTo.exactly(1,Project))
Project.is_a.append(associateWith.some(TaskSets))
TaskSets.is_a.append(linkedTo.some(Project))

TaskSets.is_a.append(identifies.exactly(1,WorkTasks))
WorkTasks.is_a.append(isIdentifiedBy.exactly(1,TaskSets))
TaskSets.is_a.append(identifies.some(WorkTasks))
WorkTasks.is_a.append(isIdentifiedBy.some(TaskSets))

WorkTasks.is_a.append(arePerformedBy.some(Team))
Team.is_a.append(performs.some(WorkTasks))
# Team restrictions
Team.is_a.append(isCommunicatedBy.some(ICTDifferent))


Team.is_a.append(isDirectedBy.exactly(1,Leadership))
Leadership.is_a.append(isLeaderOf.exactly(1,Team))
Team.is_a.append(isDirectedBy.some(Leadership))
Leadership.is_a.append(isLeaderOf.some(Team))


Team.is_a.append(isCommunicateIn.some(Communication))
Communication.is_a.append(isACommunicationWayIn.some(Team))
Communication.is_a.append(Formal|Informal)
AllDisjoint([Formal, Informal])

Team.is_a.append(cooperateThrough.some(Cooperation))
Cooperation.is_a.append(isCooperatedWayOf.some(Team))

Team.is_a.append(mustHaveATypeOf.some(Coordination))
Coordination.is_a.append(isATypeOfCoordinationIn.some(Team))
Team.is_a.append(needsToBuild.some(Trust))
Trust.is_a.append(increasesCollaborationIn.some(Team))                         
Team.is_a.append(isCohesiveWhen.some(Cohesion))
Cohesion.is_a.append(isACohesionFactor.some(Team))                         
Team.is_a.append(performanceIncreasesWith.some(KnowledgeSharing))
KnowledgeSharing.is_a.append(isATypeOfKnowledgeIn.some(Team))
Team.is_a.append(hasMotivation.some(Motivation))
Motivation.is_a.append(isAMotivationWayTo.some(Team))
Motivation.is_a.append(Reward|Compliment)
AllDisjoint([Reward, Compliment])
Team.is_a.append(isSplitedBy.some(Conflict))
Conflict.is_a.append(split.some(Team))
Team.is_a.append(isWeakenBy.some(StaffTurnover))
StaffTurnover.is_a.append(weaken.some(Team))
Team.is_a.append(mustTakeInformationFrom.some(ReliabilityOfInformation))
ReliabilityOfInformation.is_a.append(providesReliableInformationTo.some(Team))
Team.is_a.append(savesDataIn.exactly(1,DataRepositories))
DataRepositories.is_a.append(facilitateAccessToInformationIn.some(Team))
Team.is_a.append(needInWorkTo.some(ComfortEnvironment))
ComfortEnvironment.is_a.append(haveAGreatImpactTo.some(Team))


Team.is_a.append(isFacing.some(TechnicalProblems))
TechnicalProblems.is_a.append(decreasedPerformance.some(Team))

Team.is_a.append(isFrustratedBy.some(LackOfOrganizationalStructure))


LackOfOrganizationalStructure.is_a.append(frustrate.some(Team))

Team.is_a.append(need.exactly(1,Training))
Training.is_a.append(isIncreasingEfficiencyOf.exactly(1,Team))
Team.is_a.append(need.some(Training))
Training.is_a.append(isIncreasingEfficiencyOf.some(Team))
Training.is_a.append(add.exactly(1,Experience))
Experience.is_a.append(isAddedBy.exactly(1,Training))
Training.is_a.append(add.some(Experience))
Experience.is_a.append(isAddedBy.some(Training))
Team.is_a.append(hasSize.max(1,TeamSize))
Team.is_a.append(hasSize.some(TeamSize))
TeamSize.is_a.append(isTheSizeOf.some(Team))

TeamSize.is_a.append(impactOn.some(FactorsImpactedbySize))
FactorsImpactedbySize.is_a.append(isImpactedBy.some(TeamSize))
Team.is_a.append(increasesPerformanceThrough.some(Teamness))
Teamness.is_a.append(improvesPerformanceOf.some(Team))

#Process restrictions


Team.is_a.append(selectedOneOf.exactly(1,Process))
Team.is_a.append(selectedOneOf.some(Process))
Process.is_a.append(mustAppropriate.some(MarketplaceDemands))
MarketplaceDemands.is_a.append(forceTheUseOneOf.some(Process))
MarketplaceDemands.is_a.append(isResulted.some(RequirementProblem))
Process.is_a.append(hasFramework.exactly(1,ProcessFramework))
Process.is_a.append(hasFramework.some(ProcessFramework))
ProcessFramework.is_a.append(isAFrameworkOf.some(Process))
ProcessFramework.is_a.append(hasActivities.some(FrameworkActivities))
FrameworkActivities.is_a.append(isAnActivityOf.some(ProcessFramework))
FrameworkActivities.is_a.append(suffersFrom.some(RequirementProblem))

RequirementProblem.is_a.append(FaultyDefinition|RequirementsNotUnderstood|RequirementChange)
AllDisjoint([FaultyDefinition,RequirementsNotUnderstood,RequirementChange])
RequirementProblem.is_a.append(leadTo.max(8,DesignProblems))


FrameworkActivitiesPrinciples.is_a.append(isAPrinciplesOf.max(1,FrameworkActivities))
FrameworkActivitiesPrinciples.is_a.append(isAPrinciplesOf.some(FrameworkActivities))

FrameworkActivitiesPrinciples.is_a.append(notUsedCause.max(8,DesignProblems))

FrameworkActivitiesPrinciples.is_a.append(notUsedReason.max(10,CodingProblems))

FrameworkActivitiesPrinciples.is_a.append(notUsedOccasion.exactly(1,DocumentationProblems))
DocumentationProblems.is_a.append(isOccasionedByNotUsed.exactly(1,FrameworkActivitiesPrinciples))
DesignProblems.is_a.append(evolveInto.exactly(1,CodingProblems))
CodingProblems.is_a.append(shiftInto.exactly(1,DocumentationProblems))
DesignProblems.is_a.append(turnInto.exactly(1,TestingAndMaintenanceDifficult))

TestingAndMaintenanceDifficult.is_a.append(isPerhapsA.exactly(1,DesignProblems))


CodingProblems.is_a.append(convertedTo.max(7,TestingAndMaintenanceDifficult))
TestingAndMaintenanceDifficult.is_a.append(isPossiblyA.exactly(1,CodingProblems))
DocumentationProblems.is_a.append(changedTo.max(7,TestingAndMaintenanceDifficult))
TestingAndMaintenanceDifficult.is_a.append(isLikelyA.exactly(1,DocumentationProblems))


Process.is_a.append(isRelatedTo.exactly(1,DocumentationProblems))
DocumentationProblems.is_a.append(maybeTranslateTo.exactly(1,RequirementsNotUnderstood))

#Product restrictions



Product.is_a.append(hasGoal.exactly(1,Goal))
Product.is_a.append(hasGoal.some(Goal))
Goal.is_a.append(isAGoalOf.exactly(1,Product))
Goal.is_a.append(isAGoalOf.some(Product))
Goal.is_a.append(goalIsUnclear.exactly(1,bool))
Goal.is_a.append(goalIsUnclear.some(bool))

Product.is_a.append(hasScope.exactly(1,Scope))
Product.is_a.append(hasScope.some(Scope))
Scope.is_a.append(isAScopeOf.exactly(1,Product))
Scope.is_a.append(isAScopeOf.some(Product))
Scope.is_a.append(scopeIsUnclear.exactly(1,bool))
Scope.is_a.append(scopeIsUnclear.some(bool))

Product.is_a.append(hasCost.exactly(1,Cost))
Product.is_a.append(hasCost.some(Cost))
Cost.is_a.append(isACostOf.some(Product))


Cost.is_a.append(isDecreasedBy.some(GoalOfProximityToHumanResources))
GoalOfProximityToHumanResources.is_a.append(decrease.some(Cost))
GoalOfProximityToHumanResources.is_a.append(LowWages | LowOfficeCosts)
AllDisjoint([LowWages , LowOfficeCosts])

Product.is_a.append(hasTime.exactly(1,Time))
Product.is_a.append(hasTime.some(Time))
Time.is_a.append(isATimeOf.some(Product))

Time.is_a.append(isScheduledAccordingTo.some(WorkTasksScheduling))

WorkTasksScheduling.is_a.append(timeAllocation.exactly(1,str))
WorkTasksScheduling.is_a.append(timeAllocation.some(str))

WorkTasksScheduling.is_a.append(effortAllocation.exactly(1,str))
WorkTasksScheduling.is_a.append(effortAllocation.some(str))


WorkTasksScheduling.is_a.append(effortValidation.exactly(1,str))
WorkTasksScheduling.is_a.append(effortValidation.some(str))

WorkTasksScheduling.is_a.append(definedResponsibilities.some(str))
WorkTasksScheduling.is_a.append(deliveryDeadline.exactly(1,str))
WorkTasksScheduling.is_a.append(deliveryDeadline.some(str ))

Product.is_a.append(hasQuality.some(Quality))

Quality.is_a.append(dependsOn.exactly(1,QualityFactors))
QualityFactors.is_a.append(isRepresentedBy.exactly(1,Quality))
Quality.is_a.append(dependsOn.some(QualityFactors))
QualityFactors.is_a.append(isRepresentedBy.some(Quality))


Quality.is_a.append(becomesComplicateIn.some(NewnessTechnology))
NewnessTechnology.is_a.append(complicatesAchieving.some(Quality))

Quality.is_a.append(isIncreasedBy.exactly(1,StakeholderParticipationEarly))
Quality.is_a.append(isGoDownBy.max(3,SWComplexity))


SWComplexity.is_a.append(isDeterminedBy.some(SWSize))


SWSize.is_a.append(determines.exactly(1,SWComplexity))
SWSize.is_a.append(determines.some(SWComplexity))

Product.is_a.append(needsToAllocate.some(Resources))
Resources.is_a.append(ReusableSoftware|SEE|Person)
AllDisjoint([ReusableSoftware,SEE,Person])

SEE.is_a.append(HW|SWTools|NetworkResource)

# %% [markdown]
# # Creating Individuals for classes

# %%
import pandas as pd
l=0
import csv

with open("E:\project\excel\Individuals87.csv", newline='',encoding='ISO-8859-1') as csvfile:
    
    #Individuals=pd.read_csv('/Individuals85.csv', encoding='ISO-8859-1')  
    Individuals = csv.reader(csvfile, delimiter=';', quotechar='|')
    next(Individuals)
        
    for row in Individuals:
         ##print(', '.join(row))
        [gvt_performanceIn_gsd,person,FirstName,Age,Birthday,Gender,Account,YearOfExperience,
         geographical_diversity,time_zone_different,follow_the_sun_approach,work_time,
         asynchronous,synchronous,travel_costs_and_time,work_from_any_where_in_world,diversity_of_skills,
         culture_differences,language_different,company,policies,project,task_sets,work_tasks,team,leadership,formal,
         informal,cooperation,coordination,trust,cohesion,knowledge_sharing,compliment,reward,conflict,staff_turnover,
         reliability_of_information,data_repositories,comfort_environment,technical_problems,
        lack_of_organizational_structure,training,experience,team_size,factors_impacted_by_size,teamness,
        process,process_framework,framework_activities,marketplace_demands,faulty_definition,requirements_not_understood,
         requirement_change,framework_activities_principles,design_problems,coding_problems,documentation_problems,
         Testing_And_Maintenance_Difficult,product,goal,goal_is_unclear,scope,scope_is_unclear,cost,low_office_costs,low_wages,
         time,work_tasks_scheduling,time_allocation,effort_allocation,effort_validation,defined_responsibilities,delivery_deadline,
         quality,quality_factors,newness_technology,stakeholder_participation_early,sw_complexity,sw_size,reusable_software,
         hw,network_resource,sw_tools,person_country,person_company,person_skill,person_team,person_product,person_project] =row     
       # Creating Indivisual(Person)
        print("*****New Individuals***** ")
        if gvt_performanceIn_gsd !="" :
            gvt_performanceIn_gsd=onto.GVTPerformanceInGSD(gvt_performanceIn_gsd)
            print(gvt_performanceIn_gsd)
            
        if person != "" :
            person=onto.Person(person)
            # للاشخاص Data property ادخال قيم 
            person.firstName=[FirstName]
            person.age=[int(Age)]
            person.birthday=[Birthday]
            person.gender=[Gender]
            person.account=[Account]
            person.yearOfExperience=[YearOfExperience]
            print(person," Data properties ",person.firstName,person.age,person.birthday,person.gender,person.account,person.yearOfExperience)         
                               
        if geographical_diversity !="" :
            geographical_diversity=onto.GeographicalDiversity(geographical_diversity)
            print(geographical_diversity)
        if time_zone_different !="" :
            time_zone_different =onto.TimeZoneDifferent(time_zone_different)
            print(time_zone_different)
        if follow_the_sun_approach !="" :
            follow_the_sun_approach =onto.FollowTheSunApproach(follow_the_sun_approach)
            print(follow_the_sun_approach)     
        if work_time !="":
            work_time = onto.WorkTime(work_time)
            print(work_time)
        if asynchronous !="":
            asynchronous=onto.Asynchronous(asynchronous)
            print(asynchronous)
        
        if synchronous !="":
            synchronous =onto.Synchronous(synchronous)
            print(synchronous)
        
        if travel_costs_and_time !="":
            travel_costs_and_time =onto.TravelCostsAndTime(travel_costs_and_time)
            print(travel_costs_and_time)   
        
        if work_from_any_where_in_world !="":
            work_from_any_where_in_world= onto.WorkFromAnywhereInWorld(work_from_any_where_in_world)
            print(work_from_any_where_in_world) 
         
        if diversity_of_skills !="":
            diversity_of_skills  =onto.DiversityOfSkills(diversity_of_skills)
            print(diversity_of_skills) 
            
        if culture_differences !="":
            culture_differences  =CultureDifferences(culture_differences)
            print(culture_differences)     
           
        if language_different !="":
            language_different   =onto.LanguageDifferent(language_different)
            print(language_different)     
        if company !="":
            company=onto.Company(company)
            print(company)    
        if policies !="":
            policies=onto.Policies(policies)
            print(policies)   
           
 # Creating Indivisual(Project)
        if  project!="" :
            project=onto.Project(project)
            print(project)
        if  task_sets!="" :
            task_sets=onto.TaskSets(task_sets)
            print(task_sets)  
        if  work_tasks!="" :
            work_tasks=onto.WorkTasks(work_tasks)
            print(work_tasks)
        if  team!="" :
            team=onto.Team(team)
            print(team)
        if  leadership!="" :
            leadership=onto.Leadership(leadership)  
            print(leadership)                        
        if  formal!="":                              
            formal=onto.Formal(formal)
            print(formal)
        if  informal!="":
            informal=onto.Informal(informal)
            print(informal)
        
        if  cooperation!="":
            cooperation=onto.Cooperation(cooperation)
            print(cooperation)
        
        if  coordination!="":
            coordination=onto.Coordination(coordination)
            print(coordination)
        if  trust!="":
            trust=onto.Trust(trust)
            print(trust) 
         
        if  cohesion!="":
            cohesion =onto.Cohesion(cohesion)
            print(cohesion) 
            
        if  knowledge_sharing!="":
            knowledge_sharing =onto.KnowledgeSharing(knowledge_sharing)
            print(knowledge_sharing)     
           
        if  compliment!="":
            compliment=onto.Compliment(compliment)
            print(compliment)     
        if  reward!="":
            reward=onto.Reward(reward)
            print(reward) 
        if  conflict!="":
            conflict=onto.Conflict(conflict)
            print(conflict)                                 
        if  staff_turnover!="" :
            staff_turnover=onto.StaffTurnover(staff_turnover)
            print(staff_turnover)
        if  reliability_of_information!="" :
            reliability_of_information=onto.ReliabilityOfInformation(reliability_of_information)
            print(reliability_of_information)
        if  data_repositories!="" :
            data_repositories=onto.DataRepositories(data_repositories)
            print(data_repositories)
        if  comfort_environment!="" :
            comfort_environment=onto.ComfortEnvironment(comfort_environment)
            print(comfort_environment)
        if  technical_problems!="" :
            technical_problems=onto.TechnicalProblems(technical_problems)
            print(technical_problems) 
       
        if  lack_of_organizational_structure!="":
            lack_of_organizational_structure=onto.LackOfOrganizationalStructure(lack_of_organizational_structure)
            print(lack_of_organizational_structure)
        if  training!="":
            training=onto.Training(training)
            print(training)
        
        if  experience!="":
            experience=onto.Experience(experience)
            print(experience)
        
        if  team_size!="":
            team_size=onto.TeamSize(team_size)
            print(team_size)   
        
        if  factors_impacted_by_size!="":
            factors_impacted_by_size=onto.FactorsImpactedbySize(factors_impacted_by_size)
            print(factors_impacted_by_size) 
          
        if  teamness!="":
            teamness= onto.Teamness(teamness)         
            print(teamness) 
            
            
 # Creating Indivisual(Process)
        if  process!="":
            process=onto.Process(process)
            print(process)     
         
        if  process_framework!="":   
            process_framework=onto.ProcessFramework(process_framework)
            print(process_framework)    
        if  framework_activities!="":
            framework_activities=onto.FrameworkActivities(framework_activities)
            print(framework_activities)  
            
        if  marketplace_demands!="":
            marketplace_demands=onto.MarketplaceDemands(marketplace_demands)
            print(marketplace_demands)
        if  faulty_definition!="":  
            faulty_definition=onto.FaultyDefinition(faulty_definition)
            print(faulty_definition)  
        if  requirements_not_understood!="":
            requirements_not_understood=onto.RequirementsNotUnderstood(requirements_not_understood)
            print(requirements_not_understood)     
      
        if  requirement_change!="":
            requirement_change=onto.RequirementChange(requirement_change)
            print(requirement_change) 
           
        if  framework_activities_principles!="":
            framework_activities_principles=onto.FrameworkActivitiesPrinciples(framework_activities_principles)
            print(framework_activities_principles)
        if  design_problems!="":
            design_problems=onto.DesignProblems(design_problems)
            print(design_problems) 
        
        if  coding_problems!="":
            coding_problems=onto.CodingProblems(coding_problems)
            print(coding_problems) 
        if  documentation_problems!="":
            documentation_problems=onto.DocumentationProblems(documentation_problems)
            print(documentation_problems)
        if  Testing_And_Maintenance_Difficult!="":
            Testing_And_Maintenance_Difficult=onto.TestingAndMaintenanceDifficult(Testing_And_Maintenance_Difficult)
            print(Testing_And_Maintenance_Difficult)
        
        

# Creating Indivisual(Product)
        if  product!="":
            product=onto.Product(product)
            print(product) 
        if  goal!="":
            goal=onto.Goal(goal)
            #هنا يقراها سترنك من الملف لذلك عملنا مقارنة وحولنا بولين true
            if goal_is_unclear =="TRUE":
                goal.goleIsUnClear=True
            else:
                goal.goleIsUnClear=False
            
            print(goal,goal.goleIsUnClear)     
        
               
                
        if  scope!="":
            scope=onto.Scope(scope)                                                               
            if scope_is_unclear =="TRUE":#هنا يقراها سترنك من الملف لذلك عملنا مقارنة وحولنا بولين true
                scope.scopeIsUnClear=True
            else:
                scope.scopeIsUnClear=False
            print(scope,scope.scopeIsUnClear)
        if  cost!="":
            cost=onto.Cost(cost)
            print(cost)       
            
        if  low_office_costs!="":
            low_office_costs=onto.LowOfficeCosts(low_office_costs)
            print(low_office_costs)
        if  low_wages!="":
            low_wages=onto.LowWages(low_wages)
            print(low_wages)
        if  time!="":
            time=onto.Time(time)
            print(time)
        if  work_tasks_scheduling!="":
            work_tasks_scheduling=onto.WorkTasksScheduling(work_tasks_scheduling)
            work_tasks_scheduling.timeAllocation=[time_allocation]          
            work_tasks_scheduling.effortAllocation=[effort_allocation]
            work_tasks_scheduling.effortValidation=[effort_validation]
            work_tasks_scheduling.definedResponsibilities=[defined_responsibilities]
            work_tasks_scheduling.deliveryDeadline=[delivery_deadline]
            print(work_tasks_scheduling,"Has Time Allocation :",work_tasks_scheduling.timeAllocation,
                  "Has Effort Allocation :",work_tasks_scheduling.effortAllocation,"\n","Has Effort Validation :",
                 work_tasks_scheduling.effortValidation,"Has Defined Responsibilities :",work_tasks_scheduling.definedResponsibilities,"\n",
                  "Has Delivery Deadline :",work_tasks_scheduling.deliveryDeadline)
       

        if  quality!="":
            quality=onto.Quality(quality)
            print(quality)                
        if  quality_factors!="":
            quality_factors=onto.QualityFactors(quality_factors)
            print(quality_factors)    
            
        if  newness_technology!="":
            newness_technology=onto.NewnessTechnology(newness_technology)
            print(newness_technology)    
            
        if  stakeholder_participation_early!="":
            stakeholder_participation_early=onto.StakeholderParticipationEarly(stakeholder_participation_early)
            print(stakeholder_participation_early)    
            
        if  sw_complexity!="":
            sw_complexity=onto.SWComplexity(sw_complexity)          
            print(sw_complexity)   
            
        if  sw_size!="":
            sw_size=onto.SWSize(sw_size)          
            print(sw_size)                                                      
            
        if  reusable_software!="":
            reusable_software=onto.ReusableSoftware(reusable_software)         
            print(reusable_software)   
       
        if  hw!="":
            hw=onto.HW(hw)          
            print(hw) 
        if  network_resource!="":
            network_resource=onto.NetworkResource(network_resource)          
            print(network_resource)     
            
        if  sw_tools!="":
            sw_tools=onto.SWTools(sw_tools)          
            print(sw_tools)
# Out:
# *****New Individuals*****
# GvtOntoInGsd.number_of_line_of_code_pm_or_function_point_pm
# GvtOntoInGsd.person1  Data properties  ['yang'] [54] ['01/01/1970'] ['male'] ['yang@yahoo'] ['55_month']
# GvtOntoInGsd.china
# GvtOntoInGsd.GMT+8
# GvtOntoInGsd.FTS1
# GvtOntoInGsd.work_hours=9
# GvtOntoInGsd.Emails
# GvtOntoInGsd.Telephones_call
# GvtOntoInGsd.flight_costs
# GvtOntoInGsd.work_from_the_home
# GvtOntoInGsd.android_developer
# GvtOntoInGsd.individualism
# GvtOntoInGsd.mandarin_chinese
# GvtOntoInGsd.company1
# GvtOntoInGsd.personnel_policies
# GvtOntoInGsd.concept_development_projects
# GvtOntoInGsd.task_set_for_a_concept_development_projects
# GvtOntoInGsd.refinement_of_task_set_for_a_concept_development_projects
# GvtOntoInGsd.business_analysis_team
# GvtOntoInGsd.team_leaders_1
# GvtOntoInGsd.vertical_bottom-up_communication
# GvtOntoInGsd.single_strand_chain_communication
# GvtOntoInGsd.direct_cooperation
# GvtOntoInGsd.internal_coordination
# GvtOntoInGsd.cognitive_trust
# ...

# %%
AllDifferent(list(onto.individuals() ))
# Out:
# AllDisjoint([GvtOntoInGsd.number_of_line_of_code_pm_or_function_point_pm, GvtOntoInGsd.person1, GvtOntoInGsd.china, GvtOntoInGsd.GMT+8, GvtOntoInGsd.FTS1, GvtOntoInGsd.work_hours=9, GvtOntoInGsd.Emails, GvtOntoInGsd.Telephones_call, GvtOntoInGsd.flight_costs, GvtOntoInGsd.work_from_the_home, GvtOntoInGsd.android_developer, GvtOntoInGsd.individualism, GvtOntoInGsd.mandarin_chinese, GvtOntoInGsd.company1, GvtOntoInGsd.personnel_policies, GvtOntoInGsd.concept_development_projects, GvtOntoInGsd.task_set_for_a_concept_development_projects, GvtOntoInGsd.refinement_of_task_set_for_a_concept_development_projects, GvtOntoInGsd.business_analysis_team, GvtOntoInGsd.team_leaders_1, GvtOntoInGsd.vertical_bottom-up_communication, GvtOntoInGsd.single_strand_chain_communication, GvtOntoInGsd.direct_cooperation, GvtOntoInGsd.internal_coordination, GvtOntoInGsd.cognitive_trust, GvtOntoInGsd.unanimity_and_agreement_on_the_goals_of_the_group, GvtOntoInGsd.explicit_knowledge_sharing, GvtOntoInGsd.having_
# ...

# %% [markdown]
# # Visualize Ontology As a Graph With Out Individuals

# %%
#Visualize Ontology As a Graph With out Individuals
#onto.save(file="D:\\GVTPerDevOntoInGSD9.owl", format="rdfxml") #العلاقات الاصلية
#o= ontor.OntoEditor("http://www.semanticweb.org/dell/ontologies/2022/0/GVTPerDevOntoInGSD9","D:\\GVTPerDevOntoInGSD9.owl")
onto.save(filePath,format="rdfxml") #حفظ الفئات والعلاقات الى الملف الاصلي المحفوظ لكي نستخدمها في الرسم 
#يعمل الرسم بموجب الانطلوجيا التي تم حفظها واذا اردت تغير اسم الرسم احفظ كل رسم باسم جديد ولكن سوف يكون كل مرة فايل
o= ontor.OntoEditor("http://www.semanticweb.org/dell/ontologies/2023/3/"+prefix,filePath) 
o.visualize(classes=  ["GVTPerformanceInGSD","Person","GeographicalDiversity","TimeZoneDifferent","FollowTheSunApproach",
                       "WorkTime","ICTDifferent","Asynchronous","Synchronous","TravelCostsAndTime","WorkFromAnywhereInWorld",
                       "DiversityOfSkills","CultureDifferences","LanguageDifferent","Company","Policies","Project","TaskSets",
                       "WorkTasks","Team","Leadership","Communication","Formal","Informal","Cooperation","Coordination",
                       "Trust","Cohesion","KnowledgeSharing","Motivation","Compliment","Reward","Conflict","StaffTurnover",
                       "ReliabilityOfInformation","DataRepositories","ComfortEnvironment","TechnicalProblems",
                       "LackOfOrganizationalStructure","Training","Experience","TeamSize","FactorsImpactedbySize",
                        "Teamness","Process","ProcessFramework","FrameworkActivities","MarketplaceDemands","RequirementProblem",
                        "FrameworkActivitiesPrinciples","DesignProblems","CodingProblems","DocumentationProblems",
                       "TestingAndMaintenanceDifficult","Product","Goal","Scope","Cost","GoalOfProximityToHumanResources","LowOfficeCosts",
                       "LowWages","Time","WorkTasksScheduling","Quality","QualityFactors","NewnessTechnology","StakeholderParticipationEarly",
                       "SWComplexity","SWSize","Resources","ReusableSoftware","SEE","HW","NetworkResource","SWTools"] ,
    properties=["isAffectedFirstlyBy","isAffectedSecondlyBy","isAffectedThirdlyBy","isAffectedFourthlyBy","isADeveloperFor",
                "assigneTo","isDrivenBy","hasDevelopment","workIn","isBeingImplementedBy",
                "isRegulatedTheirWorkBy","isFrom","hasTimeDifferent","generate","resulted","use","reduce","enable","hasSkill","hasCulture", 
                "speak","belongTo","associateWith","identifies","arePerformedBy","isCommunicatedBy","isFtsOf","isCommunicateIn","isDirectedBy",
                "cooperateThrough","mustHaveATypeOf","needsToBuild","isCohesiveWhen","performanceIncreasesWith",
                "hasMotivation","isSplitedBy","isWeakenBy","mustTakeInformationFrom","savesDataIn","needInWorkTo",  
                "isFacing","isFrustratedBy","need","add","hasSize","impactOn","increasesPerformanceThrough",  
                 "isRelatedTo","selectedOneOf","hasFramework" ,"hasActivities","mustAppropriate","isResulted","leadTo",
                 "suffersFrom","isAPrinciplesOf","notUsedCause","notUsedReason","notUsedOccasion","evolveInto","shiftInto","turnInto","convertedTo","changedTo",
                 "maybeTranslateTo","hasGoal","hasScope","hasCost","isDecreasedBy","hasTime","isScheduledAccordingTo","hasQuality","dependsOn",
                  "becomesComplicateIn","isIncreasedBy","isGoDownBy","isDeterminedBy","needsToAllocate"], 
       tbox_only=True,  bylabel=False, lang=None, open_html=True,bgcolor="#F0F8FF", classcolor="#C0392B",font_color="#000000",
        )# radius=2, ,tbox_only=True يعرضها بدون افراد

# %% [markdown]
# # Visualize Ontology As a Graph With Individuals

# %%
#Visualize Ontology As a Graph With out Individuals
#onto.save(file="D:\\GVTPerDevOntoInGSD9.owl", format="rdfxml") #العلاقات الاصلية
#o= ontor.OntoEditor("http://www.semanticweb.org/dell/ontologies/2022/0/GVTPerDevOntoInGSD9","D:\\GVTPerDevOntoInGSD9.owl")
#filePath=drive+prefix+".owl"
#onto.save(filePath, format="rdfxml") 
o= ontor.OntoEditor("http://www.semanticweb.org/dell/ontologies/2023/3/"+prefix,filePath) 
o.visualize(classes=  ["GVTPerformanceInGSD","Person","GeographicalDiversity","TimeZoneDifferent","FollowTheSunApproach",
                       "WorkTime","ICTDifferent","Asynchronous","Synchronous","TravelCostsAndTime","WorkFromAnywhereInWorld",
                       "DiversityOfSkills","CultureDifferences","LanguageDifferent","Company","Policies","Project","TaskSets",
                       "WorkTasks","Team","Leadership","Communication","Formal","Informal","Cooperation","Coordination",
                       "Trust","Cohesion","KnowledgeSharing","Motivation","Compliment","Reward","Conflict","StaffTurnover",
                       "ReliabilityOfInformation","DataRepositories","ComfortEnvironment","TechnicalProblems",
                       "LackOfOrganizationalStructure","Training","Experience","TeamSize","FactorsImpactedbySize",
                        "Teamness","Process","ProcessFramework","FrameworkActivities","MarketplaceDemands","RequirementProblem",
                        "FrameworkActivitiesPrinciples","DesignProblems","CodingProblems","DocumentationProblems",
                       "TestingAndMaintenanceDifficult","Product","Goal","Scope","Cost","GoalOfProximityToHumanResources","LowOfficeCosts",
                       "LowWages","Time","WorkTasksScheduling","Quality","QualityFactors","NewnessTechnology","StakeholderParticipationEarly",
                       "SWComplexity","SWSize","Resources","ReusableSoftware","SEE","HW","NetworkResource","SWTools"] ,
    properties=["isAffectedFirstlyBy","isAffectedSecondlyBy","isAffectedThirdlyBy","isAffectedFourthlyBy","isADeveloperFor",
                "assigneTo","isDrivenBy","hasDevelopment","workIn","isBeingImplementedBy",
                "isRegulatedTheirWorkBy","isFrom","hasTimeDifferent","generate","resulted","use","reduce","enable","hasSkill","hasCulture", 
                "speak","belongTo","associateWith","identifies","arePerformedBy","isCommunicatedBy","isFtsOf","isCommunicateIn","isDirectedBy",
                "cooperateThrough","mustHaveATypeOf","needsToBuild","isCohesiveWhen","performanceIncreasesWith",
                "hasMotivation","isSplitedBy","isWeakenBy","mustTakeInformationFrom","savesDataIn","needInWorkTo",  
                "isFacing","isFrustratedBy","need","add","hasSize","impactOn","increasesPerformanceThrough",  
                 "isRelatedTo","selectedOneOf","hasFramework" ,"hasActivities","mustAppropriate","isResulted","leadTo",
                 "suffersFrom","isAPrinciplesOf","notUsedCause","notUsedReason","notUsedOccasion","evolveInto","shiftInto","turnInto","convertedTo","changedTo",
                 "maybeTranslateTo","hasGoal","hasScope","hasCost","isDecreasedBy","hasTime","isScheduledAccordingTo","hasQuality","dependsOn",
                  "becomesComplicateIn","isIncreasedBy","isGoDownBy","isDeterminedBy","needsToAllocate"],tbox_only=False, 
        bylabel=False, lang=None, open_html=True,bgcolor="#F2F3F4", classcolor="#C0392B",font_color="#000000",instancecolor="#28B463",
        )#radius=20,

# %% [markdown]
# # Property Assertions

# %%
#لا استطيع عمل ادخال الافراد مع الربط لانه رسم الانطولوجيا لايعمل
gvt_ins=GVTPerformanceInGSD.instances()
person_ins=Person.instances()
project_ins=Project.instances()
process_ins=Process.instances()
product_ins=Product.instances()
country_ins=GeographicalDiversity.instances()
language_ins=LanguageDifferent.instances()
country_time_ins=TimeZoneDifferent.instances()
company_ins=Company.instances()
skill_ins=DiversityOfSkills.instances()
team_ins=Team.instances()
product_ins=Product.instances()
project_ins=Project.instances()
company_ins=Company.instances()
policies_ins=Policies.instances()
FTS_ins=FollowTheSunApproach.instances()
workTime_ins=WorkTime.instances()
team_ins=Team.instances()
culture_ins=CultureDifferences.instances()
asyn_ins=Asynchronous.instances()
syn_ins=Synchronous.instances()
travel_ins=TravelCostsAndTime.instances()
work_ins=WorkFromAnywhereInWorld.instances()
team_ins=Team.instances()
leader_ins=Leadership.instances()
formal_ins=Formal.instances()
informal_ins=Informal.instances()
coop_ins=Cooperation.instances()
coor_ins=Coordination.instances()
trust_ins=Trust.instances()
cohesion_ins=Cohesion.instances()
know_ins=KnowledgeSharing.instances()
compliment_ins=Compliment.instances()
reward_ins=Reward.instances()
conflict_ins=Conflict.instances()
turnover_ins=StaffTurnover.instances()
reliability_ins=ReliabilityOfInformation.instances()
repositories_ins=DataRepositories.instances()
comfort_ins=ComfortEnvironment.instances()
techProb_ins=TechnicalProblems.instances()
stracture_ins=LackOfOrganizationalStructure.instances()
training_ins=Training.instances()
experience_ins=Experience.instances()
tsize_ins=TeamSize.instances()
fimpacted_ins=FactorsImpactedbySize.instances()
teamness_ins=Teamness.instances()
process_ins=Process.instances()
taskset_ins=TaskSets.instances()
workTask_ins=WorkTasks.instances()
p_freamwork_ins=ProcessFramework.instances()
f_activities_ins=FrameworkActivities.instances()
market_demands_ins=MarketplaceDemands.instances()
faulty_definition_ins=FaultyDefinition.instances()
r_Not_Understood_ins=RequirementsNotUnderstood.instances()
r_change_ins=RequirementChange.instances()
principles_ins=FrameworkActivitiesPrinciples.instances()
design_problems_ins=DesignProblems.instances()
coding_problems_ins=CodingProblems.instances()
Docu_problem_ins=DocumentationProblems.instances()
Testing_ins=TestingAndMaintenanceDifficult.instances()
goal_ins=Goal.instances()
scope_ins=Scope.instances()
cost_ins=Cost.instances()
low_wages_ins=LowWages.instances()
low_office_cost_ins=LowOfficeCosts.instances()
time_ins=Time.instances()
work_scheduling_ins=WorkTasksScheduling.instances()
quality_ins=Quality.instances()
quality_factors_ins=QualityFactors.instances()
newness_technology_ins=NewnessTechnology.instances()
Stakeholder_Participation_ins=StakeholderParticipationEarly.instances()
sw_complexity_ins=SWComplexity.instances()
sw_size_ins=SWSize.instances()
Reusable_SW_ins=ReusableSoftware.instances()
hw_ins=HW.instances()
sw_tools_ins=SWTools.instances()
network_resource_ins=NetworkResource.instances()



print("\n*** GVT To Person ***\n")
gvt_ins[0].isAffectedFirstlyBy=[person_ins[0],person_ins[5],person_ins[9],person_ins[25],person_ins[34],person_ins[36],
                                person_ins[21],person_ins[49],person_ins[61]]
gvt_ins[1].isAffectedFirstlyBy=[person_ins[8],person_ins[2],person_ins[31],person_ins[51]]
gvt_ins[2].isAffectedFirstlyBy=[person_ins[35],person_ins[11],person_ins[45],person_ins[33],person_ins[60]]
gvt_ins[3].isAffectedFirstlyBy=[person_ins[39],person_ins[14],person_ins[28],person_ins[18],person_ins[20]]
gvt_ins[4].isAffectedFirstlyBy=[person_ins[56],person_ins[26],person_ins[36],person_ins[6],person_ins[16]]
for i in range(len(gvt_ins)):
    print(gvt_ins[i],":Is Affected Firstly By: ",gvt_ins[i].isAffectedFirstlyBy) 

import csv
l=0
with open("E:\project\excel\Individuals87.csv", newline='') as csvfile:
    IndividualsAssertions = csv.reader(csvfile, delimiter=';', quotechar='|')# Individuals هنا يقرا قيم الجدول ويضعه في  
    next(IndividualsAssertions)#يقرا السطر الثاني لان الاول عنوان الحقول
    print(" خصائص الاشخاص والبلدان والمهارات والشركة والفريق والمنتج والمشروع \n")     
    for row in IndividualsAssertions:# بعدد الاسطرrow متغير
         #القيم التالية هي متغيرات نضع فيها القيم المقرؤة من الجدول ولازم متغيرا بعدد اعمدة الجدول لان يطلع غلط
        [gvt_performanceIn_gsd,person,FirstName,Age,Birthday,Gender,Account,YearOfExperience,
         geographical_diversity,time_zone_different,follow_the_sun_approach,work_time,
         asynchronous,synchronous,travel_costs_and_time,work_from_any_where_in_world,diversity_of_skills,
         culture_differences,language_different,company,policies,project,task_sets,work_tasks,team,leadership,formal,
         informal,cooperation,coordination,trust,cohesion,knowledge_sharing,compliment,reward,conflict,staff_turnover,
         reliability_of_information,data_repositories,comfort_environment,technical_problems,
        lack_of_organizational_structure,training,experience,team_size,factors_impacted_by_size,teamness,
        process,process_framework,framework_activities,marketplace_demands,faulty_definition,requirements_not_understood,
         requirement_change,framework_activities_principles,design_problems,coding_problems,documentation_problems,
         Testing_And_Maintenance_Difficult,product,goal,goal_is_unclear,scope,scope_is_unclear,cost,low_office_costs,low_wages,
         time,work_tasks_scheduling,time_allocation,effort_allocation,effort_validation,defined_responsibilities,delivery_deadline,
         quality,quality_factors,newness_technology,stakeholder_participation_early,sw_complexity,sw_size,reusable_software,
         hw,network_resource,sw_tools,person_country,person_company,person_skill,person_team,person_product,person_project] =row 
        # [person_country,person_company,person_skill,person_team,person_product,person_project] =row 
        # يمثل متغير يحتوي كل قيم صف من الجدول    
        #ادخال البلدان والمهارات والشركة والفريق والمنتج والمشروع         
        person_ins[l].isFrom=[country_ins[int(person_country)-1]] # لانه المصفوفة تبدا بالموقع 0 والجدول يبدا 1 نطرح 1 من قيمة المتغير 
        person_ins[l].hasSkill=[skill_ins[int(person_skill)-1]]      
        person_ins[l].workIn=[company_ins[int(person_company)-1]]
        person_ins[l].belongTo=[team_ins[int(person_team)-1]]
        person_ins[l].isADeveloperFor=[product_ins[int(person_product)-1]]                              
        person_ins[l].assigneTo=[project_ins[int(person_project)-1]] 
        print("****",person_ins[l],"****")
        print("isFrom",person_ins[l].isFrom,"hasSkill",person_ins[l].hasSkill,"belongTo",person_ins[l].belongTo,"isADeveloperFor",person_ins[l].isADeveloperFor,"assigneTo",person_ins[l].assigneTo)
        l=l+1

print("\n توزيع المشاريع على الشركات \n")
project_ins[0].isBeingImplementedBy=[company_ins[0],company_ins[1],company_ins[2],company_ins[3],company_ins[4],company_ins[5]]            
print(project_ins[0],"isBeingImplementedBy",project_ins[0].isBeingImplementedBy )
for i in range(1,len(project_ins)):#تبدي من 1 لان المشروع 0 نفذ في السطر السابق  
    project_ins[i].isBeingImplementedBy=[company_ins[i]]#المشروع الاول تطوير مفهوم يشترك فيه كل الشركات وباقي المشاريع كل مشروع مثلا لشركة
    print(project_ins[i],"isBeingImplementedBy",project_ins[i].isBeingImplementedBy )

print("\n توزيع سياسات الشركات \n")
company_ins[0].isRegulatedTheirWorkBy=[policies_ins[0]] 
company_ins[1].isRegulatedTheirWorkBy=[policies_ins[0],policies_ins[1],policies_ins[2],policies_ins[3],policies_ins[4]] 
company_ins[2].isRegulatedTheirWorkBy=[policies_ins[0],policies_ins[5],policies_ins[6]]     
company_ins[3].isRegulatedTheirWorkBy=[policies_ins[0],policies_ins[7],policies_ins[8],policies_ins[9]] 
company_ins[4].isRegulatedTheirWorkBy=[policies_ins[0],policies_ins[2],policies_ins[4]] 
company_ins[5].isRegulatedTheirWorkBy=[policies_ins[0],policies_ins[7]] 
for i in company_ins:
    print(i,"has Policies",i.isRegulatedTheirWorkBy)
print("\n توزيع الوقت واللغة للدول \n")
for i in range(len(country_ins)):
    country_ins[i].speak=[language_ins[i]]
    country_ins[i].hasTimeDifferent=[country_time_ins[i]]
    print(country_ins[i],"speak",country_ins[i].speak,"and hasTimeDifferent",country_ins[i].hasTimeDifferent)            
print("\n","نهج تتبع الشمس","\n")
FTS_ins[0].isGeneratedBy=[country_time_ins[0],country_time_ins[6],country_time_ins[7],country_time_ins[9],country_time_ins[10],country_time_ins[11],country_time_ins[12]]                        
FTS_ins[1].isGeneratedBy=[country_time_ins[0],country_time_ins[1],country_time_ins[2],country_time_ins[3],country_time_ins[4],country_time_ins[7],country_time_ins[10],country_time_ins[12]]
FTS_ins[2].isGeneratedBy=[country_time_ins[0],country_time_ins[1],country_time_ins[2],country_time_ins[3],country_time_ins[5],country_time_ins[6],country_time_ins[8],country_time_ins[9],country_time_ins[10],country_time_ins[12]]       
FTS_ins[3].isGeneratedBy=[country_time_ins[2],country_time_ins[3],country_time_ins[4],country_time_ins[5],country_time_ins[8],country_time_ins[11],country_time_ins[12]]  
FTS_ins[4].isGeneratedBy=[country_time_ins[0],country_time_ins[1],country_time_ins[2],country_time_ins[3],country_time_ins[6],country_time_ins[7],country_time_ins[9],country_time_ins[10],country_time_ins[12]]  
FTS_ins[5].isGeneratedBy=[country_time_ins[1],country_time_ins[9],country_time_ins[10],country_time_ins[12]] 
for i in range(6):
    print(FTS_ins[i],"isGeneratedBy:  ",FTS_ins[i].isGeneratedBy)
print("\n"," و الفرق توزيع وقت العمل","\n")    
FTS_ins[0].resulted=[workTime_ins[14]]               
FTS_ins[0].isFtsOf=[team_ins[0]] 
FTS_ins[1].resulted=[workTime_ins[15]] 
FTS_ins[1].isFtsOf=[team_ins[1]] 
FTS_ins[2].resulted=[workTime_ins[15]] 
FTS_ins[2].isFtsOf=[team_ins[2]] 
FTS_ins[3].resulted=[workTime_ins[14]] 
FTS_ins[3].isFtsOf=[team_ins[3]] 
FTS_ins[4].resulted=[workTime_ins[14]] 
FTS_ins[4].isFtsOf=[team_ins[4]]  
FTS_ins[5].resulted=[workTime_ins[4]] 
FTS_ins[5].isFtsOf=[team_ins[5]] 
for i in range(6):
    print(FTS_ins[i],"resulted :  ",FTS_ins[i].resulted," and",FTS_ins[i]," is FTS of",FTS_ins[i].isFtsOf)

print("\n","التنوع الثقافي للدول","\n")    
country_ins[0].hasCulture=[culture_ins[1],culture_ins[2],culture_ins[7],culture_ins[9]]               
country_ins[1].hasCulture=[culture_ins[0],culture_ins[3],culture_ins[4],culture_ins[5],culture_ins[6],culture_ins[8]] 
country_ins[2].hasCulture=[culture_ins[1],culture_ins[2],culture_ins[7],culture_ins[9]] 
country_ins[3].hasCulture=[culture_ins[1],culture_ins[2],culture_ins[4],culture_ins[7],culture_ins[9]] 
country_ins[4].hasCulture=[culture_ins[0],culture_ins[3],culture_ins[5],culture_ins[6],culture_ins[8]] 
country_ins[5].hasCulture=[culture_ins[1],culture_ins[9]] 
country_ins[6].hasCulture=[culture_ins[1],culture_ins[9]]
country_ins[7].hasCulture=[culture_ins[0],culture_ins[3],culture_ins[4],culture_ins[5],culture_ins[6],culture_ins[8]]
country_ins[8].hasCulture=[culture_ins[1],culture_ins[2],culture_ins[7],culture_ins[9]]
country_ins[9].hasCulture=[culture_ins[0],culture_ins[3],culture_ins[4],culture_ins[5],culture_ins[6],culture_ins[8]]
country_ins[10].hasCulture=[culture_ins[1],culture_ins[2],culture_ins[7],culture_ins[9]]
country_ins[11].hasCulture=[culture_ins[1],culture_ins[3],culture_ins[5],culture_ins[6],culture_ins[7],culture_ins[8]]
country_ins[12].hasCulture=[culture_ins[0],culture_ins[3],culture_ins[5],culture_ins[6],culture_ins[7],culture_ins[9]] 
for i in range(12):
    print(country_ins[i]," has culture :  ",country_ins[i].hasCulture)

print("\n","تنوع وسائل التواصل","\n")  
country_ins[0].use=[asyn_ins[3],asyn_ins[8],syn_ins[12],asyn_ins[0]]
country_ins[1].use=[syn_ins[0],syn_ins[5],syn_ins[4]]
country_ins[2].use=[asyn_ins[8],asyn_ins[6],asyn_ins[0],asyn_ins[4]]
country_ins[3].use=[asyn_ins[0],syn_ins[5],syn_ins[13]]
country_ins[4].use=[asyn_ins[2],syn_ins[3]]
country_ins[5].use=[asyn_ins[0],syn_ins[2]]
country_ins[6].use=[syn_ins[2],syn_ins[11]]
country_ins[7].use=[syn_ins[12],syn_ins[11],syn_ins[10],asyn_ins[0]]
country_ins[8].use=[asyn_ins[0],syn_ins[2]]
country_ins[9].use=[syn_ins[1],syn_ins[2],syn_ins[4],syn_ins[5]]
country_ins[10].use=[asyn_ins[4],asyn_ins[0],syn_ins[5]]
country_ins[11].use=[asyn_ins[0],asyn_ins[6],asyn_ins[4],asyn_ins[12]]
country_ins[12].use=[asyn_ins[4],asyn_ins[11],asyn_ins[5],asyn_ins[0]]
for i in range(12):
    print(country_ins[i]," use ICT :  ",country_ins[i].use)

print("\n","تقليل كلف السفر ","\n") 
for i in range(len(asyn_ins)):
     asyn_ins[i].reduce=[travel_ins[0],travel_ins[1],travel_ins[2],travel_ins[3],travel_ins[4],travel_ins[5]]
     print(asyn_ins[i]," reduce :  ",asyn_ins[i].reduce)    


print("\n","العمل من اي مكان في العالم","\n") 
for i in range(len(syn_ins)):
    syn_ins[i].enable=[work_ins[0],work_ins[1],work_ins[2],work_ins[3],work_ins[4]]
    print(syn_ins[i]," enable :  ",syn_ins[i].enable) 

print("\n","Project To Process ","\n")

project_ins[0].hasOneOfProcessDevelopment=[process_ins[6]] 
project_ins[1].hasOneOfProcessDevelopment=[process_ins[2]]    
project_ins[2].hasOneOfProcessDevelopment=[process_ins[4]]  
project_ins[3].hasOneOfProcessDevelopment=[process_ins[0]] 
project_ins[4].hasOneOfProcessDevelopment=[process_ins[5]]
for i in range(len(project_ins)):    
    print(project_ins[i],":Has One Of Process Development :  ", project_ins[i].hasOneOfProcessDevelopment)

print("\n","GVT TO Project ","\n") 
gvt_ins[0].isAffectedSecondlyBy=[project_ins[0],project_ins[1]]
gvt_ins[1].isAffectedSecondlyBy=[project_ins[2],project_ins[3],project_ins[4]]
gvt_ins[2].isAffectedSecondlyBy=[project_ins[3],project_ins[4]]
gvt_ins[3].isAffectedSecondlyBy=[project_ins[0],project_ins[1],project_ins[3],project_ins[4]]
gvt_ins[4].isAffectedSecondlyBy=[project_ins[0],project_ins[1],project_ins[3],project_ins[4]]
for i in range(len(gvt_ins)):
    print(gvt_ins[i],":Is Affected Secondly By: ",gvt_ins[i].isAffectedSecondlyBy)   
    
    
    
print("\n","Project To Task Sets ","\n") 
for i in range(len(project_ins)):
    project_ins[i].associateWith=[taskset_ins[i]]
    print(project_ins[i],":associate With :  ", project_ins[i].associateWith)

print("\n","Task Sets To Work Tasks ","\n") 
for i in range(len(taskset_ins)):
    taskset_ins[i].identifies=[workTask_ins[i]]
    print(taskset_ins[i],":identifies Work Tasks As :  ", taskset_ins[i].identifies)


print("\n","Work Tasks To Team ","\n") 
for i in range(len( taskset_ins)):
    workTask_ins[i].arePerformedBy=[team_ins[0],team_ins[1],team_ins[2],team_ins[3],team_ins[4],team_ins[5]]
    print(workTask_ins[i],":Are Performed By :  ", workTask_ins[i].arePerformedBy)









print("\n","ICT For Team","\n") 
team_ins[0].isCommunicatedBy=[asyn_ins[0],asyn_ins[4],syn_ins[12]]
team_ins[1].isCommunicatedBy=[asyn_ins[0],syn_ins[11],syn_ins[5]]
team_ins[2].isCommunicatedBy=[asyn_ins[0],syn_ins[1],asyn_ins[4]]
team_ins[3].isCommunicatedBy=[asyn_ins[0],syn_ins[13],asyn_ins[5]]
team_ins[4].isCommunicatedBy=[asyn_ins[0],asyn_ins[10],asyn_ins[6]]
team_ins[5].isCommunicatedBy=[asyn_ins[0],syn_ins[2]]
for i in range(len(team_ins)):
    print(team_ins[i],": is Communicated By  :  ",team_ins[i].isCommunicatedBy)



print("\n","قائد الفريق","\n") 
for i in range(len(team_ins)):
    team_ins[i].isDirectedBy=[leader_ins[i]] 
    print(team_ins[i],": has leader  :  ",team_ins[i].isDirectedBy)
print("\n","تواصل الفريق","\n")    
team_ins[0].isCommunicateIn=[formal_ins[0],informal_ins[0]]
team_ins[1].isCommunicateIn=[formal_ins[1],informal_ins[1]]
team_ins[2].isCommunicateIn=[formal_ins[2],informal_ins[2]]
team_ins[3].isCommunicateIn=[formal_ins[3],informal_ins[3]]
team_ins[4].isCommunicateIn=[formal_ins[2],informal_ins[0]]
team_ins[5].isCommunicateIn=[formal_ins[1],informal_ins[1]]
for i in range(len(team_ins)):
    print(team_ins[i],": Is Communicate Formal And InFormal In :  ",team_ins[i].isCommunicateIn  )

print("\n","تعاون الفريق","\n")    
for i in range(len(team_ins)):
     team_ins[i].CooperateThrough=[coop_ins[0],coop_ins[1]]
     print(team_ins[i],": is Cooperate Through :  ",team_ins[i].CooperateThrough  )
print("\n","تنسيق الفريق","\n")    
for i in range(len(team_ins)):
     team_ins[i].mustHaveATypeOf=[coor_ins[0],coor_ins[1],coor_ins[2],coor_ins[3]]
     print(team_ins[i],": Must Have A Type Of :  ",team_ins[i].mustHaveATypeOf  )

print("\n","انواع ثقة الفريق","\n")    
for i in range(len(team_ins)):
     team_ins[i].needsToBuild=[trust_ins[0],trust_ins[1]]
     print(team_ins[i],": Needs To Build :  ",team_ins[i].needsToBuild  )

print("\n","انواع تماسك الفريق","\n")    
for i in range(len(team_ins)):
     team_ins[i].isCohesiveWhen=[cohesion_ins[0],cohesion_ins[1],cohesion_ins[2],cohesion_ins[3],cohesion_ins[4],cohesion_ins[5],cohesion_ins[6],cohesion_ins[7],cohesion_ins[8],cohesion_ins[9],cohesion_ins[10]]
     print(team_ins[i],": is Cohesive When :  ",team_ins[i].isCohesiveWhen )

print("\n","مشاركة المعرفة","\n")    
for i in range(len(team_ins)):
     team_ins[i].performanceIncreasesWith=[know_ins[0],know_ins[1],know_ins[2],know_ins[3],know_ins[4],know_ins[5],know_ins[6]]
     print(team_ins[i],": performance Increases With knowledge Sharing Like :  ", team_ins[i].performanceIncreasesWith)

print("\n","تحفيز الفريق","\n")    
team_ins[0].hasMotivation=[reward_ins[0],compliment_ins[0]]
team_ins[1].hasMotivation=[reward_ins[1],compliment_ins[1]]
team_ins[2].hasMotivation=[reward_ins[2],compliment_ins[2]]
team_ins[3].hasMotivation=[reward_ins[3],compliment_ins[3]]
team_ins[4].hasMotivation=[reward_ins[4],compliment_ins[4]]
team_ins[5].hasMotivation=[reward_ins[0],compliment_ins[5]]
for i in range(len(team_ins)):
    print(team_ins[i],": Has Motivation Like :  ",team_ins[i].hasMotivation  )

print("\n","انواع صراع الفريق","\n")    
for i in range(len(team_ins)):
     team_ins[i].isSplitedBy=[conflict_ins[0],conflict_ins[1],conflict_ins[2]]
     print(team_ins[i],":is Splited By Conflict Like :  ",team_ins[i].isSplitedBy)

print("\n","ترك الموظفين للعمل","\n")    
for i in range(len(team_ins)):
     team_ins[i].isWeakenBy=[turnover_ins[0],turnover_ins[1],turnover_ins[2],turnover_ins[3]]
     print(team_ins[i],":Is Weaken By Staff Turnover Like :  ",team_ins[i].isWeakenBy) 

print("\n","وثوقية المعلومات","\n")    
for i in range(len(team_ins)):
    team_ins[i].mustTakeInformationFrom =[reliability_ins[0],reliability_ins[1],reliability_ins[2],reliability_ins[3],reliability_ins[4]]
    print(team_ins[i],":Must Take Information From :  ",team_ins[i].mustTakeInformationFrom) 
print("\n","مخازن البيانات","\n") 
team_ins[0].savesDataIn=[repositories_ins[0]]
team_ins[1].savesDataIn=[repositories_ins[1]]
team_ins[2].savesDataIn=[repositories_ins[2]]
team_ins[3].savesDataIn=[repositories_ins[3]]
team_ins[4].savesDataIn=[repositories_ins[3]]#الفريق الخامس لايستخدم شي 
for i in range(len(team_ins)):
    print(team_ins[i],":Saves Data In :  ",team_ins[i].savesDataIn)

print("\n","بيئة مريحة","\n")    
team_ins[0].needInWorkTo=[comfort_ins[0],comfort_ins[1],comfort_ins[2],comfort_ins[3],comfort_ins[4]]
team_ins[1].needInWorkTo=[comfort_ins[0],comfort_ins[1],comfort_ins[2],comfort_ins[3],comfort_ins[4]]
team_ins[2].needInWorkTo=[comfort_ins[0],comfort_ins[1],comfort_ins[2],comfort_ins[3],comfort_ins[4]]
team_ins[3].needInWorkTo=[comfort_ins[0],comfort_ins[1],comfort_ins[2],comfort_ins[3],comfort_ins[4]]
team_ins[4].needInWorkTo=[comfort_ins[0],comfort_ins[1],comfort_ins[2],comfort_ins[3],comfort_ins[4]]
team_ins[5].needInWorkTo=[comfort_ins[0],comfort_ins[1],comfort_ins[2],comfort_ins[3],comfort_ins[4]]
for i in range(len(team_ins)):
    print(team_ins[i],": Need In Work To :  ",team_ins[i].needInWorkTo)


print("\n","المشاكل التفنية ","\n")    
team_ins[0].isFacing=[techProb_ins[3]]
team_ins[1].isFacing=[techProb_ins[0],techProb_ins[3],techProb_ins[4]]
team_ins[2].isFacing=[techProb_ins[0],techProb_ins[4]]
team_ins[3].isFacing=[techProb_ins[2],techProb_ins[6]]
team_ins[4].isFacing=[techProb_ins[1],techProb_ins[4],techProb_ins[6]]
team_ins[5].isFacing=[techProb_ins[2],techProb_ins[6]]
for i in range(len(team_ins)):
    print(team_ins[i],": Is Facing Technical Problems As :  ",team_ins[i].isFacing)


print("\n","غياب الهيكل التنظيمي","\n")    
for i in range(len(team_ins)):
     team_ins[i].isFrustratedBy=[stracture_ins[0],stracture_ins[1],stracture_ins[2],stracture_ins[3],stracture_ins[4]]
     print(team_ins[i],":Is Frustrated By :  ",team_ins[i].isFrustratedBy)    
print("\n","التدريب","\n")    
for i in range(len(team_ins)):
     team_ins[i].need=[training_ins[i]]
     print(team_ins[i],":Is Need :  ", team_ins[i].need)

print("\n","الخبرة","\n")    
for i in range(len(training_ins)):
     training_ins[i].add=[experience_ins[i]]
     print(training_ins[i],":Add Experience   :  ", training_ins[i].add)

print("\n","حجم الفريق","\n")    
for i in range(len(team_ins)):
    team_ins[i].hasSize=[tsize_ins[i]]
    print(team_ins[i],":has Size  :  ", team_ins[i].hasSize)



print("\n","تأثير الحجم ","\n")
tsize_ins[0].impactOn=[fimpacted_ins[0]]
tsize_ins[1].impactOn=[fimpacted_ins[0],fimpacted_ins[1],fimpacted_ins[2],fimpacted_ins[3]]
tsize_ins[2].impactOn=[fimpacted_ins[0],fimpacted_ins[1],fimpacted_ins[2],fimpacted_ins[3]]
tsize_ins[3].impactOn=[fimpacted_ins[0]]
tsize_ins[4].impactOn=[fimpacted_ins[0],fimpacted_ins[1]]
tsize_ins[5].impactOn=[fimpacted_ins[0]]
for i in range(len(tsize_ins)):
     print("Team ",i+1," Size is",tsize_ins[i],": And impact On:  ", tsize_ins[i].impactOn)
print("\n","زيادة روح الفريق","\n")    
for i in range(len(team_ins)):
    team_ins[i].increasesPerformanceThrough=[teamness_ins[i]]
    print(team_ins[i],":increases Performance Through  :  ", team_ins[i].increasesPerformanceThrough)
    
print("\n","*** GVT To Process ***","\n")    
gvt_ins[0].isAffectedThirdlyBy=[process_ins[4],process_ins[1],process_ins[3]]                                                                                                        
gvt_ins[1].isAffectedThirdlyBy=[process_ins[0],process_ins[1],process_ins[2],process_ins[3],process_ins[4]]                                                                                                        
gvt_ins[2].isAffectedThirdlyBy=[process_ins[1],process_ins[5]]
gvt_ins[3].isAffectedThirdlyBy=[process_ins[1],process_ins[3]]
gvt_ins[4].isAffectedThirdlyBy=[process_ins[0],process_ins[2],process_ins[4],process_ins[6]]    
for i in range(len(gvt_ins)):
    print(gvt_ins[i],":Is Affected Thirdly By: ",gvt_ins[i].isAffectedThirdlyBy)     

print("\n","Process To Team ","\n") 
process_ins[6].isSelectedBy=[team_ins[0],team_ins[1],team_ins[2],team_ins[3],team_ins[4],team_ins[5]]
print(process_ins[6],":Is Selected By Teams  :  ", process_ins[6].isSelectedBy)
    

print("\n","Process To Process Framework ","\n") 
process_ins[0].hasFramework=[p_freamwork_ins[0]]
process_ins[1].hasFramework=[p_freamwork_ins[3]]
process_ins[2].hasFramework=[p_freamwork_ins[0]]
process_ins[3].hasFramework=[p_freamwork_ins[4]]
process_ins[4].hasFramework=[p_freamwork_ins[1]]
process_ins[5].hasFramework=[p_freamwork_ins[0]]
process_ins[6].hasFramework=[p_freamwork_ins[0]]
process_ins[7].hasFramework=[p_freamwork_ins[2]]
for i in range(len(process_ins)):
    print(process_ins[i],":has Freamwork  :  ",process_ins[i].hasFramework)
    
    
print("\n","Process Framework To Framework Activities ","\n") 
p_freamwork_ins[0].hasActivities=[f_activities_ins [0],f_activities_ins [1],f_activities_ins [2],f_activities_ins [3],f_activities_ins [4]]
p_freamwork_ins[1].hasActivities=[f_activities_ins [5],f_activities_ins [6],f_activities_ins [7],f_activities_ins [8],f_activities_ins [9]]
p_freamwork_ins[2].hasActivities=[f_activities_ins [1],f_activities_ins [7],f_activities_ins [10],f_activities_ins [11]]
p_freamwork_ins[3].hasActivities=[f_activities_ins [12],f_activities_ins [13],f_activities_ins [14],f_activities_ins [2],f_activities_ins [10],f_activities_ins [15],f_activities_ins [16],f_activities_ins [17],f_activities_ins [18]]
p_freamwork_ins[4].hasActivities=[f_activities_ins [5],f_activities_ins [7],f_activities_ins [3],f_activities_ins [19]]
for i in range(len(p_freamwork_ins)):
    print(p_freamwork_ins[i],":Has Activities  :  ",p_freamwork_ins[i].hasActivities,"\n")

  
print("\n","Process To Marketplace Demands ","\n")     
for i in range(len(process_ins)):
    process_ins[i].mustAppropriate=[market_demands_ins[0],market_demands_ins[1],market_demands_ins[2],market_demands_ins[3]]  
    print(process_ins[i],":must Appropriate Marketplace Demands As  :  ",process_ins[i].mustAppropriate)

print("\n"," Marketplace Demands To Requiement Problem  ","\n") 
market_demands_ins[0].isResulted=[r_Not_Understood_ins[0],r_change_ins[1]]
market_demands_ins[1].isResulted=[r_Not_Understood_ins[0],r_change_ins[0]]
market_demands_ins[2].isResulted=[faulty_definition_ins[0]]
market_demands_ins[3].isResulted=[faulty_definition_ins[0],r_change_ins[4]]
for i in range(len(market_demands_ins)):
    print(market_demands_ins[i],":is Resulted  :\n  ",market_demands_ins[i].isResulted)

print("\n"," Framework Activities To Requiement Problem  ","\n") 
f_activities_ins [0].suffersFrom=[r_change_ins[0]]
f_activities_ins [1].suffersFrom=[faulty_definition_ins[0],r_Not_Understood_ins[1],r_change_ins[4]]
f_activities_ins [2].suffersFrom=[faulty_definition_ins[0],r_Not_Understood_ins[1],r_change_ins[2],r_change_ins[3]]
f_activities_ins [3].suffersFrom=[faulty_definition_ins[0],faulty_definition_ins[2],r_Not_Understood_ins[1],r_Not_Understood_ins[2],r_Not_Understood_ins[3],r_Not_Understood_ins[4]]
f_activities_ins [4].suffersFrom=[r_change_ins[1],r_change_ins[4]]
f_activities_ins [5].suffersFrom=[faulty_definition_ins[0],faulty_definition_ins[1],faulty_definition_ins[2],r_Not_Understood_ins[0],r_change_ins[1],r_change_ins[2]]
f_activities_ins [6].suffersFrom=[r_Not_Understood_ins[0],r_Not_Understood_ins[1]]
f_activities_ins [7].suffersFrom=[r_Not_Understood_ins[1],r_Not_Understood_ins[2],r_Not_Understood_ins[3],r_Not_Understood_ins[4]]
f_activities_ins [8].suffersFrom=[faulty_definition_ins[0],faulty_definition_ins[2],r_Not_Understood_ins[1],r_Not_Understood_ins[2],r_Not_Understood_ins[3],r_Not_Understood_ins[4]]
f_activities_ins [9].suffersFrom=[r_change_ins[1],r_change_ins[4]]
f_activities_ins [10].suffersFrom=[faulty_definition_ins[0],faulty_definition_ins[2],r_Not_Understood_ins[1],r_Not_Understood_ins[2],r_Not_Understood_ins[3],r_Not_Understood_ins[4]]
f_activities_ins [11].suffersFrom=[faulty_definition_ins[0],r_Not_Understood_ins[1],r_Not_Understood_ins[2],r_Not_Understood_ins[3],r_Not_Understood_ins[4],r_change_ins[1]]
f_activities_ins [12].suffersFrom=[faulty_definition_ins[0],faulty_definition_ins[1],faulty_definition_ins[2],r_Not_Understood_ins[0],r_change_ins[1],r_change_ins[2]]
f_activities_ins [13].suffersFrom=[r_Not_Understood_ins[1],r_Not_Understood_ins[2],r_Not_Understood_ins[3],r_Not_Understood_ins[4]]
f_activities_ins [14].suffersFrom=[r_Not_Understood_ins[1],r_Not_Understood_ins[2],r_Not_Understood_ins[3],r_Not_Understood_ins[4]]
f_activities_ins [15].suffersFrom=[faulty_definition_ins[0],r_Not_Understood_ins[1],r_Not_Understood_ins[2],r_Not_Understood_ins[3],r_Not_Understood_ins[4],r_change_ins[1]]
f_activities_ins [16].suffersFrom=[faulty_definition_ins[0],r_Not_Understood_ins[1],r_Not_Understood_ins[2],r_Not_Understood_ins[3],r_Not_Understood_ins[4],r_change_ins[1]]
f_activities_ins [17].suffersFrom=[faulty_definition_ins[0],r_Not_Understood_ins[1],r_Not_Understood_ins[2],r_Not_Understood_ins[3],r_Not_Understood_ins[4],r_change_ins[1]]
f_activities_ins [18].suffersFrom=[faulty_definition_ins[0],r_Not_Understood_ins[1],r_Not_Understood_ins[2],r_Not_Understood_ins[3],r_Not_Understood_ins[4],r_change_ins[1]]
f_activities_ins [19].suffersFrom=[r_change_ins[1],r_change_ins[4]]
for i in range(len(f_activities_ins)):
    print(f_activities_ins [i],":Activity Suffers From  : ",f_activities_ins [i].suffersFrom)
    
print("\n"," Requiement Problem to Design Problem ","\n")    
faulty_definition_ins[0].leadTo=[design_problems_ins[0],design_problems_ins[2]]
faulty_definition_ins[1].leadTo=[design_problems_ins[6]]
faulty_definition_ins[2].leadTo=[design_problems_ins[3]]
r_change_ins[1].leadTo=[design_problems_ins[5]]
print(faulty_definition_ins[0],":lead To  : ",faulty_definition_ins[0].leadTo)
print(faulty_definition_ins[1],":lead To  : ",faulty_definition_ins[1].leadTo)  
print(faulty_definition_ins[2],":lead To  : ",faulty_definition_ins[2].leadTo)    
print(r_change_ins[1],":lead To  : ",r_change_ins[1].leadTo)    
    
print("\n","Framework Activities To Framework Activities principles ","\n")     
f_activities_ins[2].hasPrinciples=[principles_ins[0],principles_ins[1],principles_ins[2],principles_ins[3],principles_ins[4],principles_ins[5],principles_ins[6],principles_ins[7],principles_ins[8],principles_ins[9]]    
f_activities_ins[10].hasPrinciples=[principles_ins[10],principles_ins[11],principles_ins[12],principles_ins[13],principles_ins[14],principles_ins[15],principles_ins[16],principles_ins[17],principles_ins[18],principles_ins[19],principles_ins[20],principles_ins[21]] 
f_activities_ins[4].hasPrinciples=[principles_ins[22],principles_ins[23],principles_ins[24],principles_ins[25],principles_ins[26]]
print(f_activities_ins[2],":Has Principles  : ",f_activities_ins[2].hasPrinciples)
print(f_activities_ins[10],":Has Principles  : ",f_activities_ins[10].hasPrinciples)
print(f_activities_ins[4],":Has Principles  : ",f_activities_ins[4].hasPrinciples)


print("\n","Framework Activities principles To Design Problems ","\n")
principles_ins[1].notUsedCause=[design_problems_ins[6]]
principles_ins[3].notUsedCause=[design_problems_ins[5]]
principles_ins[4].notUsedCause=[design_problems_ins[3]]
print(principles_ins[1],":Not Used Cause  : \n",principles_ins[1].notUsedCause)
print(principles_ins[3],":Not Used Cause  : \n",principles_ins[3].notUsedCause)
print(principles_ins[4],":Not Used Cause  : \n",principles_ins[4].notUsedCause)
      
print("\n","Framework Activities principles To Coding Problems ","\n")
principles_ins[11].notUsedReason=[coding_problems_ins[0]]
principles_ins[15].notUsedReason=[coding_problems_ins[4]]
principles_ins[17].notUsedReason=[coding_problems_ins[3]]
principles_ins[20].notUsedReason=[coding_problems_ins[1],coding_problems_ins[2],coding_problems_ins[6]]
print(principles_ins[11],":Not Used Reason  : ",principles_ins[11].notUsedReason)
print(principles_ins[15],":Not Used Reason  : ",principles_ins[15].notUsedReason)
print(principles_ins[17],":Not Used Reason  : ",principles_ins[17].notUsedReason)
print(principles_ins[20],":Not Used Reason  : ",principles_ins[20].notUsedReason)            
      
print("\n","Framework Activities principles To Documentation Problems ","\n")
principles_ins[24].notUsedOccasion=[Docu_problem_ins[2]]
principles_ins[25].notUsedOccasion=[Docu_problem_ins[5]]
print(principles_ins[24],":Not Used Reason  : ",principles_ins[24].notUsedOccasion)
print(principles_ins[25],":Not Used Reason  : ",principles_ins[25].notUsedOccasion)


print("\n"," Design Problems To Coding Problems ","\n")
design_problems_ins[0].evolveInto=[coding_problems_ins[4]]
design_problems_ins[1].evolveInto=[coding_problems_ins[5]]
design_problems_ins[2].evolveInto=[coding_problems_ins[6]]
design_problems_ins[3].evolveInto=[coding_problems_ins[7]]
design_problems_ins[4].evolveInto=[coding_problems_ins[8]]
design_problems_ins[7].evolveInto=[coding_problems_ins[0]]
for i in range(len(design_problems_ins)):
    print(design_problems_ins[i],":Evolve InTo  : ",design_problems_ins[i].evolveInto)

print("\n"," Coding Problems To Documentation Problems  ","\n")
coding_problems_ins[1].shiftInto=[Docu_problem_ins[3]]
coding_problems_ins[7].shiftInto=[Docu_problem_ins[0]]
coding_problems_ins[9].shiftInto=[Docu_problem_ins[4]]
print(coding_problems_ins[1],":Evolve InTo  : ",coding_problems_ins[1].shiftInto)
print(coding_problems_ins[7],":Evolve InTo  : ",coding_problems_ins[7].shiftInto)
print(coding_problems_ins[9],":Evolve InTo  : ",coding_problems_ins[9].shiftInto)

print("\n"," Design Problems To Testing And Maintenance Difficult ","\n")
design_problems_ins[6].turnInto=[Testing_ins[6]]
design_problems_ins[7].turnInto=[Testing_ins[3]]
print(design_problems_ins[6],":Turn Into  : ",design_problems_ins[6].turnInto)
print(design_problems_ins[7],":Turn Into  : ",design_problems_ins[7].turnInto)

print("\n"," Coding Problems To Testing And Maintenance Difficult ","\n")
coding_problems_ins[9].convertedTo=[Testing_ins[0],Testing_ins[1],Testing_ins[2],Testing_ins[4]]
print(coding_problems_ins[9],":Converted To  : ",coding_problems_ins[9].convertedTo)

print("\n"," Documentation Problems To Testing And Maintenance Difficult ","\n")
Docu_problem_ins[4].changedTo=[Testing_ins[0],Testing_ins[1],Testing_ins[2],Testing_ins[4]]
Docu_problem_ins[6].changedTo=[Testing_ins[5]]
print(Docu_problem_ins[4],":Changed To  : ",Docu_problem_ins[4].changedTo)
print(Docu_problem_ins[6],":Changed To  : ",Docu_problem_ins[6].changedTo)

print("\n"," Process To Documentation Problems ","\n")
process_ins[4].isRelatedTo=[Docu_problem_ins[7]]
process_ins[7].isRelatedTo=[Docu_problem_ins[7]]
print(process_ins[4],":Is Related To  : ",process_ins[4].isRelatedTo)
print(process_ins[7],":Is Related To  : ",process_ins[7].isRelatedTo)

print("\n","  Documentation Problems To Requirements Not Understood ","\n")
Docu_problem_ins[7].mayBeTranslateTo=[r_Not_Understood_ins[1]]
print(Docu_problem_ins[7],":May Be Translate To : ",Docu_problem_ins[7].mayBeTranslateTo)


print("\n"," Process To Product ","\n")
process_ins[0].developmentWayTo=[product_ins[5]]
process_ins[1].developmentWayTo=[product_ins[9]]
process_ins[2].developmentWayTo=[product_ins[1]]
process_ins[3].developmentWayTo=[product_ins[2]]
process_ins[4].developmentWayTo=[product_ins[3],product_ins[8]]
process_ins[5].developmentWayTo=[product_ins[4],product_ins[7]]
process_ins[6].developmentWayTo=[product_ins[0],product_ins[6]]
for i in range(len(process_ins)):
    print(process_ins[i],":development Way To  :  ",process_ins[i].developmentWayTo)




print("\n"," GVT To Product ","\n")
gvt_ins[0].isAffectedFourthlyBy=[product_ins[1],product_ins[6],product_ins[7],product_ins[8]]
gvt_ins[1].isAffectedFourthlyBy=[product_ins[1],product_ins[2],product_ins[6],product_ins[7],product_ins[8]]
gvt_ins[2].isAffectedFourthlyBy=[product_ins[1],product_ins[2],product_ins[3],product_ins[4],product_ins[6],product_ins[7],product_ins[8]]
gvt_ins[3].isAffectedFourthlyBy=[product_ins[2],product_ins[3],product_ins[6],product_ins[7],product_ins[8]]
gvt_ins[4].isAffectedFourthlyBy=[product_ins[2],product_ins[3],product_ins[6],product_ins[7],product_ins[8]]
for i in range(len(gvt_ins)):
    print(gvt_ins[i],":Is Affected Fourthly By : ",gvt_ins[i].isAffectedFourthlyBy)



print("\n","  Product To Goal And Scope ","\n")
for i in range(len(product_ins)):
    product_ins[i].hasGoal=[goal_ins[i]]
    product_ins[i].hasScope=[scope_ins[i]]
    print(product_ins[i],":Has A Goal : ",product_ins[i].hasGoal,"And Is Unclear ? ",goal_ins[i].goleIsUnClear,"\n",
          product_ins[i],":Has A Scope : ",product_ins[i].hasScope,"And Is Unclear ? ",scope_ins[i].scopeIsUnClear)
    
    
print("\n","  Product To Cost ","\n")
for i in range(len(product_ins)):    
    product_ins[i].hasCost=[cost_ins[i]] 
    cost_ins[i].isDecreasedBy=[low_office_cost_ins[0],low_office_cost_ins[1],low_office_cost_ins[2],
    low_office_cost_ins[3], low_wages_ins[0],low_wages_ins[1],low_wages_ins[2]]
    print(product_ins[i],":Has Cost: ",product_ins[i].hasCost,"Is Decreased By:", cost_ins[i].isDecreasedBy)
    
print("\n","  Product To Time ","\n")
for i in range(len(product_ins)):    
    product_ins[i].hasTime=[time_ins[i]] 
    print(product_ins[i],":Has Time: ",product_ins[i].hasTime)
    
    
print("\n","Time To Work Tasks Scheduling ","\n")
time_ins[0].isScheduledAccordingTo=[work_scheduling_ins[0],work_scheduling_ins[1],work_scheduling_ins[2],work_scheduling_ins[3],
                                    work_scheduling_ins[4],work_scheduling_ins[5],work_scheduling_ins[6],work_scheduling_ins[7],
                                    work_scheduling_ins[8],work_scheduling_ins[9],work_scheduling_ins[10]]    
print(time_ins[0],":Is Scheduled According To: ",time_ins[0].isScheduledAccordingTo)

print("\n"," Work Tasks Scheduling ","\n")
for i in range(len(work_scheduling_ins)):
    print(work_scheduling_ins[i],":\n Has Time  :",work_scheduling_ins[i].timeAllocation,
                  "\n Has Effort  :",work_scheduling_ins[i].effortAllocation," \n Has Effort Validation :",
                 work_scheduling_ins[i].effortValidation,"\n Has  Responsibilities :",work_scheduling_ins[i].definedResponsibilities,
                  "\n Has Delivery Deadline :",work_scheduling_ins[i].deliveryDeadline,"\n")

    
print("\n"," Product To Quality ","\n")    
product_ins[0].hasQuality=[quality_ins[0],quality_ins[1],quality_ins[2],quality_ins[3],quality_ins[4],quality_ins[5],quality_ins[6],
                          quality_ins[7],quality_ins[8],quality_ins[9],quality_ins[10],quality_ins[11],quality_ins[12],quality_ins[13],
                          quality_ins[14],quality_ins[15]] 
    
print(product_ins[0],":Has Quality: ", product_ins[0].hasQuality)#عوامل الجودة للمنتج الاول فقط  
    
print("\n"," Quality To Quality Factors ","\n")
for i in range(len(quality_ins)):
    quality_ins[i].dependsOn=[quality_factors_ins[i]]
    print(quality_ins[i],":Depends On Factor: ", quality_ins[i].dependsOn)
    
print("\n"," Quality To Newness Technology  ","\n")    
for i in range(len(quality_ins)):
    quality_ins[i].becomesComplicateIn=[newness_technology_ins[0],newness_technology_ins[1],newness_technology_ins[2]]
    print(quality_ins[i],":Becomes Complicate In: ",quality_ins[i].becomesComplicateIn,"\n")    

print("\n"," ***Quality To Stakeholder Participation Early***  ","\n") 
quality_ins[0].isIncreasedBy=[Stakeholder_Participation_ins[0]]    
quality_ins[3].isIncreasedBy=[Stakeholder_Participation_ins[0]]    
quality_ins[10].isIncreasedBy=[Stakeholder_Participation_ins[0]] 
print(quality_ins[0],"\n",quality_ins[3],"\n",quality_ins[10],"\n",":Is Increased By: ",quality_ins[0].isIncreasedBy) 

print("\n"," *** Quality To SW Complexity ***  ","\n") 
quality_ins[1].isGoDownBy=[sw_complexity_ins[1],sw_complexity_ins[2]] 
quality_ins[2].isGoDownBy=[sw_complexity_ins[1],sw_complexity_ins[2]]
quality_ins[4].isGoDownBy=[sw_complexity_ins[1],sw_complexity_ins[2]]
quality_ins[5].isGoDownBy=[sw_complexity_ins[1],sw_complexity_ins[2]]
quality_ins[6].isGoDownBy=[sw_complexity_ins[1],sw_complexity_ins[2]] 
quality_ins[7].isGoDownBy=[sw_complexity_ins[1],sw_complexity_ins[2]] 
quality_ins[8].isGoDownBy=[sw_complexity_ins[1],sw_complexity_ins[2]] 
quality_ins[10].isGoDownBy=[sw_complexity_ins[1],sw_complexity_ins[2]] 
quality_ins[11].isGoDownBy=[sw_complexity_ins[1],sw_complexity_ins[2]] 
quality_ins[12].isGoDownBy=[sw_complexity_ins[1],sw_complexity_ins[2]] 
quality_ins[15].isGoDownBy=[sw_complexity_ins[1],sw_complexity_ins[2]] 
for i in range(len(quality_ins)):
    print(quality_ins[i],":Is Go Down By: ",quality_ins[i].isGoDownBy) 

print("\n"," ***  SW Complexity To SW Size ***  ","\n")
sw_complexity_ins[0].isDeterminedBy=[sw_size_ins[0],sw_size_ins[1]]
sw_complexity_ins[1].isDeterminedBy=[sw_size_ins[2]]
sw_complexity_ins[2].isDeterminedBy=[sw_size_ins[3]]
for i in range(len(sw_complexity_ins)):
    print(sw_complexity_ins[i],":Is Determined By: ",sw_complexity_ins[i].isDeterminedBy) 


print("\n"," ***  Product TO Resources ***  ","\n")
product_ins[0].needsToAllocate=[Reusable_SW_ins[6],hw_ins[2],hw_ins[3],sw_tools_ins[0],sw_tools_ins[2],network_resource_ins[1]]
product_ins[1].needsToAllocate=[Reusable_SW_ins[5]]
product_ins[2].needsToAllocate=[Reusable_SW_ins[1]]
product_ins[3].needsToAllocate=[Reusable_SW_ins[3],network_resource_ins[0]]
product_ins[4].needsToAllocate=[Reusable_SW_ins[5]]
product_ins[5].needsToAllocate=[network_resource_ins[2],network_resource_ins[3],network_resource_ins[4]]
product_ins[6].needsToAllocate=[network_resource_ins[2],network_resource_ins[3],network_resource_ins[4]]
product_ins[7].needsToAllocate=[Reusable_SW_ins[0],hw_ins[0],sw_tools_ins[2],network_resource_ins[2]]
product_ins[8].needsToAllocate=[Reusable_SW_ins[1],hw_ins[2]]
product_ins[9].needsToAllocate=[Reusable_SW_ins[2],sw_tools_ins[1],sw_tools_ins[2]]
for i in range(len(product_ins)):
    print(product_ins[i],":Needs To Allocate: ",product_ins[i].needsToAllocate)
# Out:
# *** GVT To Person ***
#
# GvtOntoInGsd.number_of_line_of_code_pm_or_function_point_pm :Is Affected Firstly By:  [GvtOntoInGsd.person1, GvtOntoInGsd.person6, GvtOntoInGsd.person10, GvtOntoInGsd.person26, GvtOntoInGsd.person35, GvtOntoInGsd.person37, GvtOntoInGsd.person22, GvtOntoInGsd.person50, GvtOntoInGsd.person62]
# GvtOntoInGsd.cost_per_line_of_code_or_function_point :Is Affected Firstly By:  [GvtOntoInGsd.person9, GvtOntoInGsd.person3, GvtOntoInGsd.person32, GvtOntoInGsd.person52]
# GvtOntoInGsd.quality_and_number_of_line_of_code_pm_or_function_point_pm :Is Affected Firstly By:  [GvtOntoInGsd.person36, GvtOntoInGsd.person12, GvtOntoInGsd.person46, GvtOntoInGsd.person34, GvtOntoInGsd.person61]
# GvtOntoInGsd.cycle_time :Is Affected Firstly By:  [GvtOntoInGsd.person40, GvtOntoInGsd.person15, GvtOntoInGsd.person29, GvtOntoInGsd.person19, GvtOntoInGsd.person21]
# ...

# %%
onto.save(filePath, format = "rdfxml")#لحفظ الملف قبل عمل المفسر

# %%
with onto:
    class T1 (Thing):pass
    class T2 (Thing):pass
    class T3 (Thing):pass
    class T4 (Thing):pass
    class T5 (Thing):pass
    class T6 (Thing):pass
    class T7 (Thing):pass
    class T8 (Thing):pass
    class T9 (Thing):pass
    class T10 (Thing):pass
    class T11 (Thing):pass

# %%
T1.equivalent_to.append(belongTo.some(Team)& workIn.value(onto.company1))
onto.get_instances_of(T1)
# Out:
# []

# %%
T2.equivalent_to.append(isUsedBy.value(onto.china))
onto.get_instances_of(T2)
# Out:
# []

# %%
T3.equivalent_to.append(isFrom.value(onto.germany))
onto.get_instances_of(T3)
# Out:
# []

# %%
T4.equivalent_to.append(belongTo.value(onto.development_team)& workIn.value(onto.company2))
onto.get_instances_of(T4)
# Out:
# []

# %%
T5.equivalent_to.append(generate.value(onto.FTS1))
onto.get_instances_of(T5)
# Out:
# []

# %%
T6.equivalent_to.append(speak.value(onto.hindi))
onto.get_instances_of(T6)
# Out:
# []

# %%
T7.equivalent_to.append(isTheSizeOf.value(onto.testing_team))
onto.get_instances_of(T7)
# Out:
# []

# %%
T11.equivalent_to.append(hasSize.value(onto.ten_person))
onto.get_instances_of(T11)
# Out:
# []

# %%
T8.equivalent_to.append(belongTo.value(onto.testing_team) & firstName.value("zhao" )) 
onto.get_instances_of(T8)
# Out:
# []

# %%
T9.equivalent_to.append(hasSkill.value(onto.android_developer)&(belongTo.value(onto.development_team)))
onto.get_instances_of(T9)
# Out:
# []

# %%
#T10.equivalent_to.append(isFrom.some(GeographicalDiversity)&(GeographicalDiversity.is_a.append(speak.value(onto.mandarin_chinese))))
#onto.get_instances_of(T10)

# %%
#T8.equivalent_to.append(speak.value(onto.mandarin_chinese))
#onto.get_instances_of(T8)

# %% [markdown]
# #  Reasoner

# %%
import owlready2
owlready2.JAVA_EXE ="C:\\Program Files\\Java\\jdk-19\\bin\\java.exe" #To call java virtual machine

# %%
#infer_property_values=True,infer_data_property_values=True(pellet تعمل فقط مع)
with onto:
     sync_reasoner_pellet(infer_property_values=True,infer_data_property_values=True,debug=2)
     #sync_reasoner(debug=2)
onto.save(filePath, format = "rdfxml")#لحفظ الانطلوجيا بعد عمل المفسر واضافة الفئات الجديدة
# Out:
# * Owlready2 * Running Pellet...
# ...

# %% [markdown]
# # Save Ontology On GitHub

# %%
def GitHub_save(x):# function
    global A   
    if "y" in x or "Y" in x:
        A="Yes"      
    else: 
        if "n" in x or "N" in x:
            A="No" 
        else:
            print("Wrong Answer!")
            query = input("Enter the correct Answer! Y or N:")
            GitHub_save (query)
query= input(" Do you want to save file in GitHub ? Y or N :")
GitHub_save(query)
if A=="Yes":
    webbrowser.open_new_tab(r'https://github.com/Ahmedreyadh1985sh/GvtOnto/upload') 
else:
    print("save the file in GitHub canceled")

# %% [markdown]
# # WIDOCO:A Wizard for Documenting Ontologies

# %%
os.startfile(r"C:\Users\Kh\Desktop\doc.jar")#Just put r before your normal string. It converts a normal string to a raw string

# %% [markdown]
# # Save Documenting Ontologies In GitHub

# %%
query= input(" Do you want to save ontologies documented in GitHub to publish  ? Y or N :")
GitHub_save(query)
if A=="Yes":
    webbrowser.open_new_tab(r'https://github.com/Ahmedreyadh1985sh/GvtOnto/upload') 
    
else:
    print("save ontologies documented in GitHub canceled")

# %% [markdown]
# # Call Documenting Ontologies From GitHub

# %%
webbrowser.open_new_tab(r'https://ahmedreyadh1985sh.github.io/GvtOnto/GvtOnto.html')
#os.startfile(r'C:\Users\Kh\Desktop\myDocumentation/index-en.html')

# %% [markdown]
# # Webvowl For Ontologies Visualization

# %%
webbrowser.open_new_tab(r'https://ahmedreyadh1985sh.github.io/GvtOnto/webvowl/index.html')
#استدعاء الاداة من التوثيق داقل كيث هب لانها احدث

# %%
 list(default_world.inconsistent_classes())

# %% [markdown]
# # sparql

# %%
print("person"," is from  ","country"," speak ","language"," has  ", "time")
list(default_world.sparql("""
SELECT ?x ?y ?z ?k ?q ?r
WHERE { 
# ?x GVTPDOnto:isFrom ?y
# ?y GVTPDOnto:speak ?z
# ?y GVTPDOnto:hasTimeDifferent ?k 
# ?x GVTPDOnto:belongTo ?q
# ?x GVTPDOnto:workIn ?r

} """))

# %%
list(default_world.sparql("""   
SELECT ?person ?skill
WHERE {
# ?person GVTPDOnto:hasSkill ?skill.
} """))

# %%
list(default_world.sparql("""   
SELECT ?x?y
WHERE {
# ?x GVTPDOnto:use ?y.
} """))

# %%
list(default_world.sparql("""   
SELECT ?person ?name ?team
WHERE {
#?person a GVTPDOnto:Person .
# ?person GVTPDOnto:firstName ?name.
# ?person GVTPDOnto:belongTo ?team.
Filter(?name="ahmed9")} """))

# %%
list(default_world.sparql("""   
SELECT ?x  ?y  
WHERE {

# ?x GVTPDOnto:isGeneratedBy ?y

} """))

# %%
 list(default_world.sparql("""
SELECT ?x ?y
WHERE  { 

# ?x rdfs:subClassOf ?y.  }
    """))

# %%
list(default_world.sparql("""   
SELECT ?gvt?person
WHERE {
# ?gvt GVTPDOnto:isAffectedFirstlyBy ?person


} """))

# %%
list(default_world.sparql("""   
SELECT ?gvt?project 
WHERE {

# ?gvt GVTPDOnto:isAffectedSecondlyBy ?project


} """))

# %%
list(default_world.sparql("""   
SELECT ?gvt?process 
WHERE {

# ?gvt GVTPDOnto:isAffectedThirdlyBy ?process


} """))

# %%
list(default_world.sparql("""   
SELECT ?gvt?product
WHERE {

# ?gvt GVTPDOnto:isAffectedFourthlyBy ?product

} """))

# %%
list(default_world.sparql("""   
SELECT ?x  ?y  
WHERE {

# ?x GVTPDOnto:hasFramework ?y

} """))

# %%
list(default_world.sparql("""   
SELECT ?x  ?y  ?z 
WHERE {

# ?x GVTPDOnto:hasFramework ?y
# ?y GVTPDOnto:hasActivities ?z
} """))

# %%
list(default_world.sparql("""   
SELECT ?x  ?z 
WHERE {
# ?x GVTPDOnto:hasPrinciples ?z
} """))
